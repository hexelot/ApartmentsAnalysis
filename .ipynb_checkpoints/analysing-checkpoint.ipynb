# %% [markdown]
# # Analysis of Apartmets for Sale in Baku

# %% [markdown]
# ---------------------------------------

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('./data.csv', converters={'Locations': pd.eval})
df.head(5)
# Out:
#         ID    Seller      Category  \
# 0  2827728     Owner  Kohna tikili
# 1  2760725  Agentlik   Yeni tikili
# 2  2872711     Owner   Yeni tikili
# 3  2881028  Agentlik   Yeni tikili
# 4  2898312     Owner  Kohna tikili
#
#                                          Locations   Price Currency  Rooms  \
# 0  [Memar Acami m., Nasimi r., 4-cu mikrorayon q.]   89500      AZN      2
# 1                       [Binaqadi r., Bilacari q.]   75653      AZN      2
# 2                                   [Narimanov r.]  155000      AZN      2
# 3                                       [Xatai r.]   86500      AZN      2
# 4                    [Nizami r., 8-ci kilometr q.]   85000      AZN      2
#
#    Area  Floor
# 0  45.0      3
# 1  72.1      2
# 2  97.0      9
# 3  71.0      5
# 4  45.0      2

# %%
pd.set_option('display.max_rows', None) # to display all rows completely

# %%
df.describe()
# Out:
#                  ID         Price        Rooms           Area         Floor
# count  2.784900e+04  2.784900e+04  27849.00000   27849.000000  27849.000000
# mean   2.830468e+06  2.048658e+05      2.82854     119.518934      8.024848
# std    2.217638e+05  1.829435e+05      0.95033    1259.504222      4.969964
# min    2.494300e+04  9.900000e+01      1.00000      12.000000      1.000000
# 25%    2.840979e+06  1.100000e+05      2.00000      70.000000      4.000000
# 50%    2.887768e+06  1.580000e+05      3.00000      96.200000      7.000000
# 75%    2.903138e+06  2.400000e+05      3.00000     135.000000     12.000000
# max    2.917435e+06  4.665000e+06     19.00000  161000.000000     27.000000

# %% [markdown]
# #### Remove duplicate rows if they exist

# %%
if len(df) - len(df['ID'].unique()) != 0:
    df = df.drop_duplicates(subset=['ID'])

# %% [markdown]
# #### Convert prices in USD to AZN if they exist

# %%
if 'USD' in df['Currency'].unique():
    df.loc[df['Currency'] == 'USD', 'Price'] = df['Price']*1.7
    df.loc[df['Currency'] == 'USD', 'Currency'] = 'AZN'

# %%
df['Locations'].explode().value_counts()
# Out:
# Yasamal r.               5523
# Nasimi r.                4545
# Xatai r.                 4298
# Narimanov r.             3359
# Nizami r.                1902
# Binaqadi r.              1773
# Yeni Yasamal q.          1272
# Inshaatchilar m.         1266
# Sabail r.                1192
# Shah Ismayil Xatai m.    1164
# Yasamal q.               1015
# Ahmadli q.                989
# Elmlar Akademiyasi m.     971
# Nariman Narimanov m.      957
# Hazi Aslanov m.           907
# Memar Acami m.            894
# 28 May m.                 815
# 8-ci kilometr q.          732
# Qara Qarayev m.           693
# Nizami m.                 658
# Ahmadli m.                634
# 20 Yanvar m.              595
# 9-cu mikrorayon q.        518
# Neftchilar m.             498
# Hazi Aslanov q.           470
# 8-ci mikrorayon q.        427
# Ganclik m.                424
# Sahil m.                  388
# Xalqlar Dostlugu m.       378
# Absheron r.               375
# 8 Noyabr m.               373
# 4-cu mikrorayon q.        347
# Sabunchu r.               343
# Azadliq Prospekti m.      335
# Suraxani r.               334
# Masazir q.                299
# Badamdar q.               291
# Ichari Shahar m.          289
# Bakixanov q.              254
# 7-ci mikrorayon q.        228
# Nasimi m.                 195
# Bayil q.                  190
# 3-cu mikrorayon q.        160
# Ag shahar q.              159
# Yeni Gunashli q.          128
# 6-ci mikrorayon q.        122
# 5-ci mikrorayon q.        111
# Bilacari q.                90
# 1-ci mikrorayon q.         86
# Kohna Gunashli q.          85
# Hovsan q.                  83
# 2-ci mikrorayon q.         60
# Qarachuxur q.              51
# Qaradag r.                 50
# Kubinka q.                 43
# Nardaran q.                40
# Darnagul m.                40
# M.A.Rasulzada q.           37
# Xazar r.                   37
# Lokbatan q.                34
# Koroglu m.                 29
# Avtovagzal m.              29
# Binaqadi q.                16
# Xutor q.                   15
# Mammadli q.                14
# Buzovna q.                 13
# Mehdiabad q.               12
# Boyukshor q.               12
# Gunashli q.                12
# Massiv D q.                11
# Ceyranbatan q.             10
# Zig q.                     10
# 20-ci saha q.               9
# NZS q.                      9
# Bina q.                     7
# Bakmil m.                   7
# Mardakan q.                 7
# Zabrat q.                   6
# Amircan q.                  6
# Yeni Suraxani q.            5
# Sahil q.                    5
# Sabunchu q.                 5
# Massiv A q.                 4
# Mashtaga q.                 4
# Keshla q.                   4
# Massiv V q.                 3
# Alat q.                     3
# Ulduz m.                    3
# Hokmali q.                  2
# Pirallahi r.                2
# Shixov q.                   2
# Novxani q.                  2
# 28 May q.                   2
# Suraxani q.                 2
# Saray q.                    2
# Sangachal q.                2
# Qobustan q.                 1
# Yeni Ramana q.              1
# Shimal DRES q.              1
# Bulbula q.                  1
# Mushfiqabad q.              1
# Xocasan q.                  1
# Massiv B q.                 1
# Ramana q.                   1
# Sulutapa q.                 1
# Name: Locations, dtype: int64

# %%
# df.loc[df['Floor'] == max(df['Floor'])]

# %%
locs = df['Locations'].explode().value_counts()

locs = dict(locs)
lists = sorted(locs.items()) # sorted by key, return a list of tuples
x, y = zip(*lists) # unpack a list of pairs into two tuples

plt.figure(figsize=(10,20))
plt.barh(x, y)
plt.title("Num of Houses in each region")
plt.xlabel("Counts")
plt.ylabel("Regions")
plt.show()

# %%
rayon = df.loc['m.' in [x[-2:] for x in df['Locations'].tolist()]]
rayon
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [64], in <cell line: 1>()
# ----> 1 rayon = df.loc['m.' in [x[-2:] for x in df['Locations'].tolist()]]
#       2 rayon
#
# File c:\users\dolbosvilli\appdata\local\programs\python\python38\lib\site-packages\pandas\core\indexing.py:967, in _LocationIndexer.__getitem__(self, key)
#     964 axis = self.axis or 0
#     966 maybe_callable = com.apply_if_callable(key, self.obj)
# --> 967 return self._getitem_axis(maybe_callable, axis=axis)
#
# File c:\users\dolbosvilli\appdata\local\programs\python\python38\lib\site-packages\pandas\core\indexing.py:1201, in _LocIndexer._getitem_axis(self, key, axis)
#    1198         return self.obj.iloc[tuple(indexer)]
#    1200 # fall thru to straight lookup
# -> 1201 self._validate_key(key, axis)
#    1202 return self._get_label(key, axis=axis)
#
# File c:\users\dolbosvilli\appdata\local\programs\python\python38\lib\site-packages\pandas\core\indexing.py:1011, in _LocIndexer._validate_key(self, key, axis)
#    1001 @doc(_LocationIndexer._validate_key)
#    1002 def _validate_key(self, key, axis: int):
#    1003     # valid for a collection of labels (we check their presence later)
#    1004     # slice of labels (where start-end in labels)
#    1005     # slice of integers (only if in the labels)
#    1006     # boolean not in slice and with boolean index
#    1007     if isinstance(key, bool) and not (
#    1008         is_bool_dtype(self.obj._get_axis(axis))
#    1009         or self.obj._get_axis(axis).dtype.name == "boolean"
#    1010     ):
# -> 1011         raise KeyError(
#    1012             f"{key}: boolean label can not be used without a boolean index"
#    1013         )
#    1015     if isinstance(key, slice) and (
#    1016         isinstance(key.start, bool) or isinstance(key.stop, bool)
#    1017     ):
#    1018         raise TypeError(f"{key}: boolean values can not be used in a slice")
#
# KeyError: 'False: boolean label can not be used without a boolean index'

# %%
print('yes') if 'm.' in [[y[-2:] for y in x] for x in df['Locations']] else print('no')
# Out:
# no

# %%
a = ['Memar Acami m.', 'Nasimi r.', '4-cu mikrorayon q.']

if 'm.' in [x[-2:] for x in a]:
    print('yes')
# Out:
# yes

# %%
for x,y in df.iterrows():
    print(x,y['Locations'])
# Out:
# 0 ['Memar Acami m.', 'Nasimi r.', '4-cu mikrorayon q.']
# 1 ['Binaqadi r.', 'Bilacari q.']
# 2 ['Narimanov r.']
# 3 ['Xatai r.']
# 4 ['Nizami r.', '8-ci kilometr q.']
# 5 ['Ganclik m.', 'Narimanov r.']
# 6 ['Nasimi m.', 'Binaqadi r.', '6-ci mikrorayon q.']
# 7 ['Ichari Shahar m.', 'Sabail r.']
# 8 ['Nariman Narimanov m.', 'Narimanov r.']
# 9 ['Yasamal r.', 'Yasamal q.']
# 10 ['Hazi Aslanov m.', 'Xatai r.', 'Hazi Aslanov q.']
# 11 ['Narimanov r.']
# 12 ['Azadliq Prospekti m.', 'Binaqadi r.', '8-ci mikrorayon q.']
# 13 ['Memar Acami m.', 'Nasimi r.', '4-cu mikrorayon q.']
# 14 ['Nizami m.', 'Yasamal r.']
# 15 ['Absheron r.', 'Masazir q.']
# 16 ['Narimanov r.']
# 17 ['Nizami m.', 'Yasamal r.']
# 18 ['Xatai r.', 'Ahmadli q.']
# 19 ['Sabunchu r.', 'Bakixanov q.']
# 20 ['20 Yanvar m.', 'Nasimi r.', '1-ci mikrorayon q.']
# 21 ['Inshaatchilar m.', 'Yasamal r.', 'Yeni Yasamal q.']
# 22 ['Narimanov r.']
# 23 ['Neftchilar m.', 'Nizami r.', '8-ci kilometr q.']
# 24 ['Nizami m.', 'Nasimi r.']
# 25 ['Xatai r.']
# 26 ['Sabail r.']
# 27 ['20 Yanvar m.', 'Yasamal r.', 'Yasamal q.']
# 28 ['Xatai r.', 'Ahmadli q.']
# 29 ['Narimanov r.']
# 30 ['Narimanov r.']
# 31 ['Elmlar Akademiyasi m.', 'Yasamal r.']
# 32 ['Sabunchu r.', 'Yeni Ramana q.']
# 33 ['Absheron r.', 'Masazir q.']
# 34 ['Nasimi r.']
# 35 ['Hazi Aslanov m.', 'Xatai r.', 'Ahmadli q.']
# 36 ['Ahmadli m.', 'Xatai r.', 'Ahmadli q.']
# 37 ['Elmlar Akademiyasi m.', 'Yasamal r.']
# 38 ['Elmlar Akademiyasi m.', 'Yasamal r.']
# 39 ['28 May m.', 'Nasimi r.']
# 40 ['20 Yanvar m.', 'Yasamal r.']
# 41 ['Memar Acami m.', 'Nasimi r.', '4-cu mikrorayon q.']
# 42 ['Binaqadi r.', '9-cu mikrorayon q.']
# 43 ['Nasimi m.', 'Binaqadi r.', '6-ci mikrorayon q.']
# 44 ['Absheron r.', 'Masazir q.']
# 45 ['Nasimi r.']
# 46 ['Yasamal r.', 'Yeni Yasamal q.']
# 47 ['Memar Acami m.', '20 Yanvar m.', 'Nasimi r.']
# 48 ['8 Noyabr m.', 'Nasimi r.']
# 49 ['Memar Acami m.', 'Nasimi r.', '3-cu mikrorayon q.']
# 50 ['20 Yanvar m.', 'Memar Acami m.', 'Nasimi r.', '2-ci mikrorayon q.']
# 51 ['Sahil m.', 'Ichari Shahar m.', 'Sabail r.']
# 52 ['Neftchilar m.', 'Nizami r.']
# 53 ['Shah Ismayil Xatai m.', 'Xatai r.']
# 54 ['Narimanov r.']
# 55 ['Binaqadi r.', '9-cu mikrorayon q.']
# 56 ['Binaqadi r.', '9-cu mikrorayon q.']
# 57 ['Sabunchu r.', 'Nardaran q.']
# 59 ['Nasimi r.']
# 61 ['Elmlar Akademiyasi m.', 'Yasamal r.']
# 62 ['Inshaatchilar m.', 'Yasamal r.']
# 63 ['Neftchilar m.', 'Nizami r.']
# 64 ['Nasimi r.', '3-cu mikrorayon q.']
# 65 ['Binaqadi r.', '9-cu mikrorayon q.']
# 66 ['Yasamal r.']
# 67 ['Elmlar Akademiyasi m.', 'Yasamal r.', 'Yasamal q.']
# 68 ['Memar Acami m.', 'Nasimi r.', '3-cu mikrorayon q.']
# 69 ['Sabail r.', 'Bayil q.']
# 70 ['Yasamal r.']
# 71 ['20 Yanvar m.', 'Yasamal r.']
# 72 ['Nizami r.', '8-ci kilometr q.']
# 73 ['Ahmadli m.', 'Xatai r.']
# 74 ['Xatai r.', 'Ahmadli q.']
# 75 ['Neftchilar m.', 'Nizami r.']
# 76 ['Xatai r.']
# 77 ['Qara Qarayev m.', 'Nizami r.', '8-ci kilometr q.']
# 78 ['Elmlar Akademiyasi m.', 'Yasamal r.']
# 79 ['Binaqadi r.', '9-cu mikrorayon q.']
# 80 ['Nizami r.']
# 81 ['Xatai r.', 'Ag shahar q.']
# 82 ['Ahmadli m.', 'Xatai r.']
# 83 ['Xatai r.']
# 84 ['28 May m.', 'Nasimi r.']
# 85 ['Absheron r.', 'Novxani q.']
# 86 ['Xatai r.']
# 87 ['Binaqadi r.', '7-ci mikrorayon q.']
# 88 ['Hazi Aslanov m.', 'Xatai r.']
# 89 ['Xatai r.', 'Ahmadli q.']
# 90 ['Hazi Aslanov m.', 'Xatai r.']
# 91 ['Qara Qarayev m.', 'Nizami r.']
# 92 ['Qara Qarayev m.', 'Nizami r.']
# 93 ['Nizami r.']
# 94 ['Xatai r.']
# 95 ['Xatai r.']
# 96 ['Nizami r.']
# 97 ['Hazi Aslanov m.', 'Xatai r.']
# 98 ['Inshaatchilar m.', 'Yasamal r.']
# 99 ['Memar Acami m.', 'Nasimi r.', '4-cu mikrorayon q.']
# 100 ['Nizami m.', 'Nasimi r.']
# 101 ['Nizami m.', 'Nasimi r.']
# 102 ['Nizami m.', 'Nasimi r.']
# 103 ['Sabail r.', 'Badamdar q.']
# 104 ['Inshaatchilar m.', 'Yasamal r.', 'Yasamal q.']
# 105 ['Shah Ismayil Xatai m.', 'Xatai r.']
# 106 ['Binaqadi r.', '9-cu mikrorayon q.']
# 107 ['Inshaatchilar m.', 'Yasamal r.', 'Yeni Yasamal q.']
# 108 ['Narimanov r.']
# 109 ['Yasamal r.', 'Yeni Yasamal q.']
# 110 ['Shah Ismayil Xatai m.', 'Xatai r.']
# 111 ['Shah Ismayil Xatai m.', 'Xatai r.']
# 112 ['Narimanov r.']
# 113 ['Yasamal r.', 'Yasamal q.']
# 114 ['Sabail r.']
# 115 ['Shah Ismayil Xatai m.', 'Xatai r.']
# 116 ['Narimanov r.']
# 117 ['Neftchilar m.', 'Nizami r.']
# 118 ['Xatai r.', 'Ag shahar q.']
# 119 ['Inshaatchilar m.', 'Yasamal r.', 'Yasamal q.']
# 120 ['Sabail r.', 'Bayil q.']
# 121 ['Yasamal r.']
# 122 ['Qara Qarayev m.', 'Nizami r.']
# 123 ['Nizami r.', '8-ci kilometr q.']
# 124 ['Nasimi m.', 'Nasimi r.']
# 125 ['Ahmadli m.', 'Xatai r.']
# 126 ['8 Noyabr m.', 'Nasimi r.']
# 127 ['Narimanov r.']
# 128 ['Shah Ismayil Xatai m.', 'Xatai r.']
# 129 ['Narimanov r.']
# 130 ['28 May m.', 'Narimanov r.']
# 131 ['Memar Acami m.', 'Binaqadi r.', '9-cu mikrorayon q.']
# 132 ['Xatai r.', 'Hazi Aslanov q.']
# 133 ['Nasimi r.']
# 134 ['Sabail r.', 'Badamdar q.']
# 135 ['Nasimi r.']
# 136 ['Suraxani r.', 'Yeni Gunashli q.']
# 137 ['Yasamal r.', 'Yeni Yasamal q.']
# 138 ['8 Noyabr m.', 'Nasimi r.', '3-cu mikrorayon q.']
# 139 ['Elmlar Akademiyasi m.', 'Yasamal r.']
# 140 ['Nasimi r.']
# 141 ['Memar Acami m.', 'Nasimi r.', '3-cu mikrorayon q.']
# 142 ['Nasimi r.']
# 143 ['Sabail r.', 'Badamdar q.']
# 146 ['Hazi Aslanov m.', 'Xatai r.', 'Hazi Aslanov q.']
# 147 ['Xatai r.', 'Hazi Aslanov q.']
# 148 ['Inshaatchilar m.', 'Yasamal r.', 'Yeni Yasamal q.']
# 149 ['Yasamal r.', 'Yeni Yasamal q.']
# 150 ['Xatai r.']
# 151 ['Shah Ismayil Xatai m.', 'Xatai r.']
# 152 ['Narimanov r.']
# 153 ['Yasamal r.', 'Yeni Yasamal q.']
# 154 ['Narimanov r.']
# 155 ['Narimanov r.']
# 156 ['Binaqadi r.', '8-ci mikrorayon q.']
# 157 ['Binaqadi r.', '9-cu mikrorayon q.']
# 158 ['Nariman Narimanov m.', 'Narimanov r.']
# 159 ['Nasimi m.', 'Binaqadi r.', '9-cu mikrorayon q.']
# 160 ['Nasimi r.']
# 161 ['Binaqadi r.', '7-ci mikrorayon q.']
# 162 ['Xatai r.', 'Hazi Aslanov q.']
# 163 ['Binaqadi r.', '7-ci mikrorayon q.']
# 164 ['Memar Acami m.', 'Nasimi r.', '4-cu mikrorayon q.']
# 165 ['Ahmadli m.', 'Xatai r.', 'Ahmadli q.']
# 166 ['Memar Acami m.', 'Nasimi r.', '4-cu mikrorayon q.']
# 167 ['Ganclik m.', 'Narimanov r.']
# 169 ['Memar Acami m.', 'Nasimi r.', '4-cu mikrorayon q.']
# 170 ['Nasimi r.']
# 171 ['Inshaatchilar m.', 'Yasamal r.']
# 172 ['Memar Acami m.', 'Nasimi r.', '4-cu mikrorayon q.']
# 173 ['Nizami r.']
# 174 ['Qara Qarayev m.', 'Nizami r.']
# 175 ['Elmlar Akademiyasi m.', 'Yasamal r.', 'Yasamal q.']
# 176 ['Shah Ismayil Xatai m.', 'Xatai r.', 'Ag shahar q.']
# 177 ['Yasamal r.', 'Yeni Yasamal q.']
# 178 ['Narimanov r.']
# 179 ['Inshaatchilar m.', 'Yasamal r.', 'Yasamal q.']
# 180 ['Ganclik m.', 'Narimanov r.']
# 181 ['Xalqlar Dostlugu m.', 'Nizami r.', '8-ci kilometr q.']
# 182 ['Memar Acami m.', 'Nasimi r.', '4-cu mikrorayon q.']
# 183 ['Yasamal r.']
# 184 ['Nasimi r.']
# 185 ['Suraxani r.', 'Qarachuxur q.']
# 186 ['Yasamal r.', 'Yeni Yasamal q.']
# 187 ['Memar Acami m.', 'Nasimi r.', '4-cu mikrorayon q.']
# 188 ['Memar Acami m.', 'Nasimi r.', '3-cu mikrorayon q.']
# 189 ['Yasamal r.', 'Yeni Yasamal q.']
# 190 ['Elmlar Akademiyasi m.', 'Yasamal r.', 'Yasamal q.']
# 191 ['20 Yanvar m.', 'Memar Acami m.', 'Nasimi r.', '1-ci mikrorayon q.']
# 192 ['Binaqadi r.', '9-cu mikrorayon q.']
# 193 ['Ganclik m.', 'Narimanov r.']
# 194 ['Inshaatchilar m.', 'Yasamal r.', 'Yasamal q.']
# 195 ['Sabail r.']
# 196 ['Xatai r.']
# 197 ['Binaqadi r.', '7-ci mikrorayon q.']
# 198 ['28 May m.', 'Nasimi r.']
# 199 ['Nizami m.', 'Yasamal r.']
# 200 ['Binaqadi r.', 'Bilacari q.']
# 201 ['Nariman Narimanov m.', 'Narimanov r.']
# 202 ['Nariman Narimanov m.', 'Narimanov r.']
# 203 ['Memar Acami m.', '20 Yanvar m.', 'Binaqadi r.']
# 204 ['Xalqlar Dostlugu m.', 'Nizami r.', '8-ci kilometr q.']
# 205 ['Ganclik m.', 'Narimanov r.']
# 206 ['Narimanov r.']
# 207 ['Narimanov r.']
# 208 ['20 Yanvar m.', 'Yasamal r.', 'Yasamal q.']
# 209 ['Memar Acami m.', '20 Yanvar m.', 'Nasimi r.', '5-ci mikrorayon q.']
# 210 ['Yasamal r.']
# 211 ['Suraxani r.', 'Yeni Gunashli q.']
# 212 ['Nasimi r.']
# 213 ['Qara Qarayev m.', 'Nizami r.', '8-ci kilometr q.']
# 214 ['Hazi Aslanov m.', 'Xatai r.', 'Hazi Aslanov q.']
# 215 ['Yasamal r.', 'Yeni Yasamal q.']
# 216 ['Narimanov r.']
# 217 ['Yasamal r.']
# 218 ['Memar Acami m.', 'Yasamal r.']
# 219 ['Elmlar Akademiyasi m.', 'Yasamal r.', 'Yasamal q.']
# 220 ['Inshaatchilar m.', 'Yasamal r.', 'Yasamal q.']
# 221 ['20 Yanvar m.', 'Memar Acami m.', 'Nasimi r.', '1-ci mikrorayon q.']
# 222 ['Nizami m.', 'Yasamal r.']
# 223 ['Ganclik m.', 'Narimanov r.']
# 224 ['Ichari Shahar m.', 'Sabail r.']
# 225 ['Sabunchu r.', 'Nardaran q.']
# 226 ['Memar Acami m.', 'Nasimi r.', '4-cu mikrorayon q.']
# 227 ['Ichari Shahar m.', 'Sabail r.']
# 228 ['Yasamal r.', 'Yeni Yasamal q.']
# 229 ['Nasimi r.']
# 230 ['Narimanov r.']
# 231 ['Nasimi r.']
# 232 ['Nariman Narimanov m.', 'Narimanov r.']
# 233 ['Narimanov r.']
# 234 ['Narimanov r.']
# 235 ['Azadliq Prospekti m.', 'Binaqadi r.']
# 236 ['Narimanov r.']
# 237 ['Nasimi m.', 'Binaqadi r.', '6-ci mikrorayon q.']
# 238 ['Qara Qarayev m.', 'Nizami r.']
# 239 ['Absheron r.']
# 240 ['Yasamal r.']
# 241 ['Sabail r.', 'Badamdar q.']
# 242 ['28 May m.', 'Nasimi r.']
# 243 ['Binaqadi r.', '9-cu mikrorayon q.']
# 244 ['Yasamal r.', 'Yasamal q.']
# 245 ['Yasamal r.', 'Yasamal q.']
# 246 ['Yasamal r.', 'Yeni Yasamal q.']
# 247 ['Nasimi r.']
# 248 ['Nariman Narimanov m.', 'Narimanov r.']
# 249 ['20 Yanvar m.', 'Nasimi r.', '1-ci mikrorayon q.']
# 250 ['Yasamal r.', 'Yeni Yasamal q.']
# 251 ['Binaqadi r.', '7-ci mikrorayon q.']
# 252 ['Memar Acami m.', 'Nasimi r.', '5-ci mikrorayon q.']
# 253 ['Nasimi r.']
# 254 ['Nasimi r.']
# 255 ['Xatai r.', 'Ahmadli q.']
# 256 ['Azadliq Prospekti m.', 'Binaqadi r.', '8-ci mikrorayon q.']
# 257 ['Xatai r.', 'NZS q.']
# 258 ['Nasimi r.', '1-ci mikrorayon q.']
# 259 ['Nariman Narimanov m.', 'Narimanov r.']
# 260 ['Binaqadi r.', '9-cu mikrorayon q.']
# 261 ['Neftchilar m.', 'Nizami r.', '8-ci kilometr q.']
# 262 ['20 Yanvar m.', 'Nasimi r.', '1-ci mikrorayon q.']
# 263 ['Nasimi r.']
# 264 ['Nariman Narimanov m.', 'Narimanov r.']
# 265 ['Elmlar Akademiyasi m.', 'Yasamal r.', 'Yasamal q.']
# 266 ['Narimanov r.']
# 267 ['Narimanov r.']
# 268 ['Elmlar Akademiyasi m.', 'Yasamal r.']
# 269 ['Sahil m.', 'Sabail r.']
# 270 ['Elmlar Akademiyasi m.', 'Yasamal r.']
# 271 ['8 Noyabr m.', 'Nasimi r.']
# 272 ['Qara Qarayev m.', 'Nizami r.']
# 273 ['Ganclik m.', 'Narimanov r.']
# 274 ['Nizami m.', 'Nasimi r.', 'Kubinka q.']
# 275 ['Yasamal r.']
# 276 ['Nasimi r.']
# 277 ['Nariman Narimanov m.', 'Narimanov r.']
# 278 ['Nariman Narimanov m.', 'Narimanov r.']
# 279 ['Nasimi m.', 'Binaqadi r.', '6-ci mikrorayon q.']
# 280 ['Nariman Narimanov m.', 'Narimanov r.']
# 281 ['Binaqadi r.', 'Xutor q.']
# 282 ['8 Noyabr m.', 'Yasamal r.', 'Yasamal q.']
# 283 ['Binaqadi r.', '7-ci mikrorayon q.']
# 284 ['Narimanov r.']
# 285 ['Azadliq Prospekti m.', 'Binaqadi r.', '8-ci mikrorayon q.']
# 286 ['Ahmadli m.', 'Hazi Aslanov m.', 'Xatai r.']
# 287 ['Nariman Narimanov m.', 'Narimanov r.']
# 288 ['Binaqadi r.']
# 289 ['Narimanov r.']
# 290 ['Nasimi r.']
# 291 ['Nizami m.', 'Yasamal r.']
# 292 ['Ganclik m.', 'Narimanov r.']
# 293 ['Narimanov r.']
# 294 ['Suraxani r.', 'Hovsan q.']
# 295 ['Nariman Narimanov m.', 'Narimanov r.']
# 296 ['Ahmadli m.', 'Xatai r.', 'Ahmadli q.']
# 297 ['Ahmadli m.', 'Xatai r.', 'Ahmadli q.']
# 298 ['Shah Ismayil Xatai m.', 'Xatai r.', 'Ag shahar q.']
# 299 ['Inshaatchilar m.', 'Yasamal r.']
# 300 ['28 May m.', 'Nasimi r.']
# 301 ['Shah Ismayil Xatai m.', 'Xatai r.']
# 302 ['Memar Acami m.', 'Nasimi r.', '5-ci mikrorayon q.']
# 303 ['Nasimi m.', 'Binaqadi r.']
# 304 ['Ganclik m.', 'Narimanov r.']
# 305 ['Neftchilar m.', 'Nizami r.', '8-ci kilometr q.']
# 306 ['Absheron r.', 'Masazir q.']
# 307 ['Binaqadi r.', '9-cu mikrorayon q.']
# 308 ['Shah Ismayil Xatai m.', 'Xatai r.']
# 309 ['Nasimi r.']
# 310 ['28 May m.', 'Nasimi r.']
# 311 ['Sabail r.']
# 313 ['Nizami m.', 'Nasimi r.']
# 314 ['Xatai r.', 'Ahmadli q.']
# 315 ['Xatai r.']
# 316 ['Shah Ismayil Xatai m.', 'Xatai r.', 'Ag shahar q.']
# 317 ['Xatai r.', 'Ahmadli q.']
# 318 ['Yasamal r.', 'Yasamal q.']
# 319 ['20 Yanvar m.', 'Memar Acami m.', 'Nasimi r.', '1-ci mikrorayon q.']
# 320 ['Sabail r.']
# 321 ['Sabail r.', 'Badamdar q.']
# 322 ['20 Yanvar m.', 'Memar Acami m.', '8 Noyabr m.', 'Nasimi r.', '3-cu mikrorayon q.']
# 323 ['Binaqadi r.', '8-ci mikrorayon q.']
# 324 ['Inshaatchilar m.', 'Yasamal r.']
# 325 ['Nizami m.', 'Yasamal r.']
# 326 ['Nizami r.']
# 327 ['Nizami m.', 'Yasamal r.', 'Yasamal q.']
# 328 ['Neftchilar m.', 'Nizami r.', '8-ci kilometr q.']
# 329 ['Nariman Narimanov m.', 'Narimanov r.']
# 330 ['Nariman Narimanov m.', 'Narimanov r.']
# 331 ['Nariman Narimanov m.', 'Narimanov r.']
# 332 ['Nariman Narimanov m.', 'Narimanov r.']
# 333 ['Nariman Narimanov m.', 'Narimanov r.']
# 334 ['Nariman Narimanov m.', 'Narimanov r.']
# 335 ['Nariman Narimanov m.', 'Narimanov r.']
# 336 ['Shah Ismayil Xatai m.', 'Xatai r.']
# 337 ['Memar Acami m.', 'Nasimi r.', '3-cu mikrorayon q.']
# 338 ['Binaqadi r.', 'Bilacari q.']
# 339 ['Hazi Aslanov m.', 'Xatai r.']
# 340 ['Nariman Narimanov m.', 'Narimanov r.']
# 341 ['Nariman Narimanov m.', 'Narimanov r.']
# 342 ['Absheron r.', 'Mehdiabad q.']
# 343 ['Nizami m.', 'Yasamal r.']
# 344 ['Yasamal r.']
# 345 ['Narimanov r.']
# 347 ['Hazi Aslanov m.', 'Xatai r.']
# 348 ['Binaqadi r.', '9-cu mikrorayon q.']
# 350 ['Nasimi r.']
# 351 ['Narimanov r.']
# 352 ['Narimanov r.']
# 353 ['Nasimi r.']
# 354 ['Nariman Narimanov m.', 'Narimanov r.']
# 355 ['28 May m.', 'Nasimi r.']
# 356 ['8 Noyabr m.', 'Nasimi r.']
# 357 ['Yasamal r.', 'Yeni Yasamal q.']
# 358 ['Ahmadli m.', 'Xatai r.']
# 359 ['Narimanov r.']
# 360 ['Binaqadi r.', '9-cu mikrorayon q.']
# 361 ['Yasamal r.']
# 362 ['Yasamal r.']
# 363 ['Yasamal r.']
# 364 ['8 Noyabr m.', 'Nasimi r.']
# 365 ['28 May m.', 'Nasimi r.']
# 367 ['Suraxani r.', 'Massiv D q.']
# 370 ['Nizami r.', '8-ci kilometr q.']
# 371 ['Ichari Shahar m.', 'Sabail r.']
# 372 ['Ahmadli m.', 'Xatai r.']
# 373 ['Neftchilar m.', 'Nizami r.']
# 374 ['20 Yanvar m.', 'Yasamal r.']
# 375 ['Yasamal r.', 'Yeni Yasamal q.']
# 376 ['Binaqadi r.', '9-cu mikrorayon q.']
# 377 ['Inshaatchilar m.', 'Yasamal r.', 'Yasamal q.']
# 378 ['Memar Acami m.', 'Nasimi r.']
# 379 ['Elmlar Akademiyasi m.', 'Yasamal r.']
# 380 ['20 Yanvar m.', 'Yasamal r.']
# 381 ['Xatai r.']
# 382 ['Nasimi r.']
# 383 ['Nasimi r.']
# 384 ['Nasimi r.']
# 385 ['Absheron r.', 'Masazir q.']
# 386 ['Nasimi r.', 'Kubinka q.']
# 387 ['Nariman Narimanov m.', 'Narimanov r.']
# 388 ['Yasamal r.', 'Yeni Yasamal q.']
# 389 ['Narimanov r.']
# 390 ['Suraxani r.', 'Qarachuxur q.']
# 391 ['Shah Ismayil Xatai m.', 'Xatai r.']
# 392 ['Narimanov r.']
# 393 ['Sabunchu r.', 'Nardaran q.']
# 394 ['Binaqadi r.', '7-ci mikrorayon q.']
# 395 ['Yasamal r.', 'Yasamal q.']
# 398 ['Shah Ismayil Xatai m.', 'Xatai r.']
# 399 ['Binaqadi r.', '8-ci mikrorayon q.']
# 400 ['Nariman Narimanov m.', 'Narimanov r.']
# 401 ['Yasamal r.']
# 402 ['Yasamal r.', 'Yeni Yasamal q.']
# 403 ['Binaqadi r.', '9-cu mikrorayon q.']
# 404 ['Inshaatchilar m.', 'Yasamal r.', 'Yasamal q.']
# 405 ['Shah Ismayil Xatai m.', 'Xatai r.']
# 406 ['Inshaatchilar m.', 'Yasamal r.']
# 407 ['Elmlar Akademiyasi m.', 'Yasamal r.']
# 408 ['Sabunchu r.', 'Bakixanov q.']
# 409 ['Binaqadi r.']
# 410 ['Binaqadi r.', '8-ci mikrorayon q.']
# 411 ['Neftchilar m.', 'Nizami r.']
# 412 ['Nasimi m.', 'Binaqadi r.', '9-cu mikrorayon q.']
# 413 ['Inshaatchilar m.', 'Yasamal r.', 'Yasamal q.']
# 414 ['28 May m.', 'Nasimi r.']
# 415 ['Yasamal r.']
# 416 ['Xalqlar Dostlugu m.', 'Nizami r.']
# 417 ['Memar Acami m.', 'Nasimi r.', '4-cu mikrorayon q.']
# 418 ['Yasamal r.', 'Yeni Yasamal q.']
# 419 ['8 Noyabr m.', 'Nasimi r.']
# 421 ['Nasimi r.']
# 422 ['Xatai r.', 'Hazi Aslanov q.']
# 423 ['Ahmadli m.', 'Xatai r.', 'Ahmadli q.']
# 426 ['Binaqadi r.', '7-ci mikrorayon q.']
# 427 ['Shah Ismayil Xatai m.', 'Xatai r.']
# 428 ['Inshaatchilar m.', 'Yasamal r.']
# 429 ['Elmlar Akademiyasi m.', 'Yasamal r.']
# 430 ['Neftchilar m.', 'Nizami r.']
# 431 ['Azadliq Prospekti m.', 'Binaqadi r.', '8-ci mikrorayon q.']
# 432 ['Yasamal r.', 'Yasamal q.']
# 433 ['Binaqadi r.', '9-cu mikrorayon q.']
# 434 ['Yasamal r.', 'Yeni Yasamal q.']
# 435 ['Memar Acami m.', 'Nasimi r.', '4-cu mikrorayon q.']
# 436 ['Yasamal r.']
# 437 ['Yasamal r.', 'Yeni Yasamal q.']
# 438 ['Shah Ismayil Xatai m.', 'Xatai r.']
# 439 ['Ahmadli m.', 'Xatai r.']
# 440 ['Shah Ismayil Xatai m.', 'Xatai r.']
# 441 ['20 Yanvar m.', 'Memar Acami m.', 'Nasimi r.']
# 442 ['Xalqlar Dostlugu m.', 'Nizami r.']
# 443 ['Nasimi r.']
# 444 ['Memar Acami m.', 'Nasimi r.', '4-cu mikrorayon q.']
# 445 ['Nasimi r.', '4-cu mikrorayon q.']
# 446 ['Nasimi r.']
# 447 ['Hazi Aslanov m.', 'Xatai r.']
# 448 ['Nasimi r.']
# 450 ['Binaqadi r.', '8-ci mikrorayon q.']
# 451 ['Absheron r.', 'Masazir q.']
# 456 ['Memar Acami m.', 'Nasimi r.', '5-ci mikrorayon q.']
# 457 ['Elmlar Akademiyasi m.', 'Yasamal r.', 'Yasamal q.']
# 458 ['Ichari Shahar m.', 'Sabail r.']
# 460 ['Absheron r.', 'Masazir q.']
# 461 ['Nizami m.', 'Yasamal r.']
# 462 ['Xatai r.', 'Hazi Aslanov q.']
# 463 ['Xatai r.', 'Ahmadli q.']
# 464 ['Nasimi r.']
# 465 ['Nasimi r.']
# 466 ['Yasamal r.', 'Yeni Yasamal q.']
# 467 ['Yasamal r.', 'Yeni Yasamal q.']
# 468 ['Yasamal r.', 'Yeni Yasamal q.']
# 469 ['Sabunchu r.']
# 470 ['Elmlar Akademiyasi m.', 'Yasamal r.']
# 471 ['Nariman Narimanov m.', 'Narimanov r.']
# 472 ['Shah Ismayil Xatai m.', 'Xatai r.']
# 473 ['20 Yanvar m.', 'Yasamal r.']
# 474 ['Nariman Narimanov m.', 'Narimanov r.']
# 475 ['Shah Ismayil Xatai m.', 'Xatai r.']
# 476 ['Nasimi r.']
# 478 ['Absheron r.', 'Masazir q.']
# 479 ['Binaqadi r.', '7-ci mikrorayon q.']
# 481 ['Yasamal r.']
# 482 ['Nasimi r.']
# 483 ['Sabail r.', 'Badamdar q.']
# 484 ['Shah Ismayil Xatai m.', 'Xatai r.']
# 485 ['Nasimi r.']
# 486 ['Memar Acami m.', 'Nasimi r.', '5-ci mikrorayon q.']
# 487 ['Memar Acami m.', 'Nasimi r.', '4-cu mikrorayon q.']
# 488 ['Memar Acami m.', 'Nasimi r.', '4-cu mikrorayon q.']
# 490 ['Nasimi r.']
# 491 ['Nasimi r.']
# 492 ['Nasimi r.']
# 493 ['Yasamal r.', 'Yeni Yasamal q.']
# 494 ['Yasamal r.', 'Yeni Yasamal q.']
# 495 ['Nizami r.']
# 496 ['Narimanov r.']
# 497 ['Inshaatchilar m.', 'Yasamal r.', 'Yasamal q.']
# 498 ['Yasamal r.', 'Yeni Yasamal q.']
# 500 ['Narimanov r.']
# 501 ['Xatai r.', 'Hazi Aslanov q.']
# 502 ['Yasamal r.', 'Yeni Yasamal q.']
# 503 ['Sabail r.']
# 505 ['Sabunchu r.', 'Nardaran q.']
# 507 ['Nasimi m.', 'Binaqadi r.', '9-cu mikrorayon q.']
# 511 ['Narimanov r.']
# 512 ['Sabunchu r.', 'Bakixanov q.']
# 513 ['Xatai r.']
# 514 ['Shah Ismayil Xatai m.', 'Xatai r.']
# 515 ['Nizami m.', 'Yasamal r.', 'Yasamal q.']
# 516 ['Inshaatchilar m.', 'Yasamal r.', 'Yasamal q.']
# 517 ['Neftchilar m.', 'Nizami r.', '8-ci kilometr q.']
# 518 ['20 Yanvar m.', 'Memar Acami m.', 'Nasimi r.', '1-ci mikrorayon q.']
# 519 ['Binaqadi r.', 'Bilacari q.']
# 522 ['Binaqadi r.', '9-cu mikrorayon q.']
# 523 ['20 Yanvar m.', 'Nasimi r.', '1-ci mikrorayon q.']
# 524 ['Yasamal r.', 'Yeni Yasamal q.']
# 527 ['Nasimi r.']
# 529 ['Inshaatchilar m.', 'Yasamal r.', 'Yasamal q.']
# 530 ['Yasamal r.', 'Yeni Yasamal q.']
# 531 ['Yasamal r.', 'Yasamal q.']
# 532 ['Narimanov r.']
# 533 ['Nariman Narimanov m.', 'Narimanov r.']
# 534 ['Yasamal r.', 'Elmlar Akademiyasi m.']
# 535 ['Inshaatchilar m.', 'Yasamal r.', 'Yasamal q.']
# 536 ['Memar Acami m.', 'Nasimi r.']
# 537 ['Yasamal r.']
# 538 ['Memar Acami m.', 'Nasimi r.', '4-cu mikrorayon q.']
# 539 ['Yasamal r.', 'Yasamal q.']
# 540 ['Elmlar Akademiyasi m.', 'Yasamal r.', 'Yasamal q.']
# 541 ['Elmlar Akademiyasi m.', 'Yasamal r.', 'Yasamal q.']
# 542 ['Elmlar Akademiyasi m.', 'Yasamal r.', 'Yasamal q.']
# 543 ['Inshaatchilar m.', 'Yasamal r.', 'Yasamal q.']
# 544 ['Nasimi r.']
# 545 ['Azadliq Prospekti m.', 'Binaqadi r.', '8-ci mikrorayon q.']
# 546 ['Inshaatchilar m.', 'Yasamal r.']
# 547 ['Elmlar Akademiyasi m.', 'Yasamal r.', 'Yasamal q.']
# 548 ['Absheron r.', 'Masazir q.']
# 549 ['Nasimi r.']
# 550 ['Azadliq Prospekti m.', 'Binaqadi r.', '8-ci mikrorayon q.']
# 551 ['Nasimi r.']
# 552 ['Elmlar Akademiyasi m.', 'Yasamal r.', 'Yasamal q.']
# 553 ['Shah Ismayil Xatai m.', 'Xatai r.']
# 554 ['Binaqadi r.', '7-ci mikrorayon q.']
# 555 ['Narimanov r.']
# 556 ['Yasamal r.', 'Yasamal q.']
# 557 ['Narimanov r.']
# 558 ['Sabunchu r.', 'Bakixanov q.']
# 559 ['Nariman Narimanov m.', 'Narimanov r.']
# 560 ['Inshaatchilar m.', 'Yasamal r.', 'Yeni Yasamal q.']
# 561 ['Azadliq Prospekti m.', 'Binaqadi r.', '8-ci mikrorayon q.']
# 562 ['28 May m.', 'Nasimi r.']
# 563 ['Yasamal r.', 'Yeni Yasamal q.']
# 564 ['28 May m.', 'Nasimi r.']
# 565 ['Nizami m.', 'Nasimi r.', 'Kubinka q.']
# 566 ['Yasamal r.']
# 567 ['Nasimi m.', 'Binaqadi r.', '6-ci mikrorayon q.']
# 568 ['Memar Acami m.', '20 Yanvar m.', 'Nasimi r.', '3-cu mikrorayon q.']
# 569 ['Shah Ismayil Xatai m.', 'Xatai r.']
# 570 ['Nariman Narimanov m.', 'Narimanov r.']
# 571 ['Yasamal r.', 'Yasamal q.']
# 572 ['Nasimi r.']
# 573 ['Narimanov r.']
# 574 ['Binaqadi r.']
# 575 ['Elmlar Akademiyasi m.', 'Yasamal r.']
# 576 ['Yasamal r.']
# 577 ['Shah Ismayil Xatai m.', 'Xatai r.']
# 578 ['Absheron r.', 'Masazir q.']
# 579 ['Xatai r.']
# 580 ['Neftchilar m.', 'Nizami r.']
# 582 ['Yasamal r.', 'Yeni Yasamal q.']
# 583 ['Yasamal r.', 'Yeni Yasamal q.']
# 584 ['Nasimi r.']
# 585 ['20 Yanvar m.', 'Nasimi r.', '1-ci mikrorayon q.']
# 586 ['Ichari Shahar m.', 'Sabail r.']
# 587 ['Qara Qarayev m.', 'Nizami r.', '8-ci kilometr q.']
# 588 ['Narimanov r.']
# 589 ['Nizami r.']
# 590 ['Nasimi r.']
# 591 ['Nariman Narimanov m.', 'Narimanov r.']
# 592 ['Nasimi r.']
# 593 ['Nasimi r.']
# 594 ['Sahil m.', 'Sabail r.']
# 595 ['Absheron r.', 'Masazir q.']
# 596 ['Shah Ismayil Xatai m.', 'Xatai r.']
# 597 ['Xatai r.', 'Ahmadli q.']
# 598 ['Nasimi r.']
# 599 ['Binaqadi r.', '9-cu mikrorayon q.']
# 600 ['Suraxani r.', 'Yeni Gunashli q.']
# 601 ['Xatai r.']
# 602 ['Xatai r.']
# 603 ['Ganclik m.', 'Narimanov r.']
# 604 ['Xatai r.']
# 605 ['Ichari Shahar m.', 'Sabail r.']
# 607 ['Xatai r.']
# 609 ['Narimanov r.']
# 610 ['Nasimi r.', '3-cu mikrorayon q.']
# 611 ['Binaqadi r.']
# 612 ['Inshaatchilar m.', 'Yasamal r.']
# 613 ['20 Yanvar m.', 'Yasamal r.']
# 614 ['Xatai r.']
# 615 ['Inshaatchilar m.', 'Yasamal r.']
# 616 ['Neftchilar m.', 'Nizami r.']
# 617 ['Hazi Aslanov m.', 'Xatai r.']
# 618 ['Azadliq Prospekti m.', 'Binaqadi r.', '7-ci mikrorayon q.']
# 620 ['Suraxani r.']
# 621 ['Azadliq Prospekti m.', 'Binaqadi r.', '8-ci mikrorayon q.']
# 622 ['Xatai r.', 'Ahmadli q.']
# 623 ['Nizami m.', 'Yasamal r.']
# 624 ['Elmlar Akademiyasi m.', 'Yasamal r.', 'Yasamal q.']
# 626 ['Neftchilar m.', 'Nizami r.']
# 627 ['Nasimi r.']
# 628 ['Xatai r.', 'Ahmadli q.']
# 629 ['Xatai r.', 'Ahmadli q.']
# 630 ['Shah Ismayil Xatai m.', 'Xatai r.']
# 631 ['Nariman Narimanov m.', 'Narimanov r.']
# 632 ['Narimanov r.']
# 634 ['Sabail r.']
# 635 ['Memar Acami m.', 'Nasimi r.']
# 636 ['Ahmadli m.', 'Xatai r.', 'Ahmadli q.']
# 637 ['Inshaatchilar m.', 'Yasamal r.', 'Yeni Yasamal q.']
# 638 ['Sahil m.', 'Sabail r.']
# 639 ['Sabunchu r.', 'Bakixanov q.']
# 640 ['Sabunchu r.', 'Bakixanov q.']
# 641 ['Nasimi r.']
# 642 ['Yasamal r.']
# 643 ['Xatai r.']
# 644 ['Nizami m.', 'Nizami r.']
# 645 ['Xatai r.', 'Ahmadli q.']
# 646 ['Narimanov r.']
# 647 ['Narimanov r.']
# 648 ['28 May m.', 'Nasimi r.']
# 649 ['Binaqadi r.']
# 650 ['Xatai r.']
# 651 ['Narimanov r.']
# 652 ['Shah Ismayil Xatai m.', 'Xatai r.']
# 653 ['Shah Ismayil Xatai m.', 'Xatai r.']
# 654 ['Shah Ismayil Xatai m.', 'Xatai r.']
# 655 ['20 Yanvar m.', 'Yasamal r.', 'Yasamal q.']
# 656 ['Yasamal r.']
# 657 ['Memar Acami m.', 'Nasimi r.']
# 658 ['Binaqadi r.', '9-cu mikrorayon q.']
# 659 ['Nizami m.', 'Nasimi r.']
# 662 ['Narimanov r.']
# 663 ['Binaqadi r.', '9-cu mikrorayon q.']
# 664 ['Memar Acami m.', 'Binaqadi r.', '9-cu mikrorayon q.']
# 665 ['Nasimi r.']
# 666 ['Ahmadli m.', 'Xatai r.']
# 667 ['Memar Acami m.', 'Nasimi r.', '4-cu mikrorayon q.']
# 668 ['Suraxani r.', 'Amircan q.']
# 669 ['Nasimi r.']
# 670 ['28 May m.', 'Narimanov r.']
# 671 ['Binaqadi r.']
# 672 ['Ahmadli m.', 'Xatai r.', 'Ahmadli q.']
# 673 ['Absheron r.', 'Masazir q.']
# 674 ['Yasamal r.', 'Yeni Yasamal q.']
# 675 ['Xatai r.', 'Ahmadli q.']
# 676 ['Neftchilar m.', 'Nizami r.']
# 677 ['Hazi Aslanov m.', 'Xatai r.']
# 678 ['Inshaatchilar m.', 'Yasamal r.', 'Yasamal q.']
# 679 ['Nasimi r.']
# 680 ['Sabail r.']
# 681 ['Nasimi r.']
# 682 ['Xatai r.']
# 683 ['28 May m.', 'Sahil m.', 'Sabail r.']
# 684 ['Xatai r.', 'Ahmadli q.']
# 685 ['28 May m.', 'Sahil m.', 'Nasimi r.']
# 686 ['Nasimi r.']
# 688 ['Xatai r.']
# 692 ['Narimanov r.']
# 693 ['Nasimi r.']
# 694 ['Sahil m.', 'Nasimi r.']
# 695 ['28 May m.', 'Sahil m.', 'Sabail r.']
# 696 ['Yasamal r.']
# 697 ['Narimanov r.']
# 698 ['Hazi Aslanov m.', 'Xatai r.', 'Hazi Aslanov q.']
# 699 ['Hazi Aslanov m.', 'Ahmadli m.', 'Xatai r.', 'Ahmadli q.']
# 700 ['Yasamal r.']
# 701 ['Yasamal r.', 'Yeni Yasamal q.']
# 702 ['Memar Acami m.', 'Nasimi r.', '4-cu mikrorayon q.']
# 703 ['Xatai r.']
# 704 ['Binaqadi r.', '9-cu mikrorayon q.']
# 705 ['28 May m.', 'Nasimi r.']
# 706 ['8 Noyabr m.', 'Nasimi r.']
# 707 ['Narimanov r.']
# 708 ['Narimanov r.']
# 709 ['8 Noyabr m.', 'Nasimi r.']
# 710 ['Narimanov r.']
# 711 ['Elmlar Akademiyasi m.', 'Yasamal r.']
# 712 ['Hazi Aslanov m.', 'Xatai r.']
# 713 ['8 Noyabr m.', 'Nasimi r.']
# 714 ['Qara Qarayev m.', 'Nizami r.', '8-ci kilometr q.']
# 715 ['Nariman Narimanov m.', 'Narimanov r.']
# 716 ['Nasimi r.']
# 717 ['Suraxani r.', 'Yeni Gunashli q.']
# 720 ['Binaqadi r.', '9-cu mikrorayon q.']
# 721 ['Nizami m.', 'Nasimi r.', 'Kubinka q.']
# 722 ['Elmlar Akademiyasi m.', 'Yasamal r.', 'Yasamal q.']
# 723 ['Hazi Aslanov m.', 'Xatai r.']
# 724 ['Memar Acami m.', 'Nasimi r.']
# 725 ['Yasamal r.']
# 726 ['Nasimi r.']
# 727 ['Elmlar Akademiyasi m.', 'Yasamal r.']
# 728 ['Qara Qarayev m.', 'Nizami r.', '8-ci kilometr q.']
# 729 ['Binaqadi r.']
# 730 ['Binaqadi r.']
# 731 ['Nasimi r.']
# 732 ['Narimanov r.']
# 733 ['Nasimi r.']
# 734 ['8 Noyabr m.', 'Narimanov r.']
# 735 ['Ganclik m.', 'Narimanov r.']
# 736 ['Absheron r.', 'Masazir q.']
# 737 ['Qara Qarayev m.', 'Nizami r.', '8-ci kilometr q.']
# 738 ['Shah Ismayil Xatai m.', 'Xatai r.']
# 739 ['Xatai r.']
# 740 ['Binaqadi r.', '7-ci mikrorayon q.']
# 742 ['Yasamal r.']
# 744 ['Narimanov r.']
# 745 ['Nasimi r.']
# 748 ['Binaqadi r.', '7-ci mikrorayon q.']
# 749 ['Binaqadi r.', '7-ci mikrorayon q.']
# 750 ['Binaqadi r.', '7-ci mikrorayon q.']
# 751 ['Narimanov r.']
# 752 ['20 Yanvar m.', 'Yasamal r.']
# 753 ['20 Yanvar m.', 'Yasamal r.']
# 754 ['Sabail r.', 'Bayil q.']
# 755 ['Inshaatchilar m.', 'Yasamal r.']
# 756 ['Narimanov r.']
# 757 ['8 Noyabr m.', 'Nasimi r.']
# 758 ['Memar Acami m.', 'Nasimi r.', '4-cu mikrorayon q.']
# 759 ['Yasamal r.', 'Yeni Yasamal q.']
# 760 ['Nizami r.']
# 761 ['Nasimi r.']
# 763 ['Nizami r.']
# 764 ['Yasamal r.']
# 766 ['Nariman Narimanov m.', 'Narimanov r.']
# 767 ['Shah Ismayil Xatai m.', 'Xatai r.']
# 768 ['Yasamal r.', 'Yeni Yasamal q.']
# 769 ['Binaqadi r.', '9-cu mikrorayon q.']
# 770 ['28 May m.', 'Nasimi r.']
# 772 ['Suraxani r.']
# 773 ['Nasimi r.']
# 774 ['Narimanov r.']
# 776 ['Nizami r.']
# 777 ['Nariman Narimanov m.', 'Narimanov r.']
# 778 ['Yasamal r.', 'Yeni Yasamal q.']
# 779 ['20 Yanvar m.', 'Nasimi r.']
# 780 ['Binaqadi r.', '9-cu mikrorayon q.']
# 781 ['Xatai r.', 'Hazi Aslanov q.']
# 782 ['Nizami m.', 'Yasamal r.']
# 783 ['Qara Qarayev m.', 'Nizami r.', '8-ci kilometr q.']
# 784 ['Yasamal r.', 'Yeni Yasamal q.']
# 785 ['Binaqadi r.', '9-cu mikrorayon q.']
# 786 ['Neftchilar m.', 'Nizami r.', '8-ci kilometr q.']
# 787 ['Nasimi r.']
# 788 ['Sabail r.']
# 789 ['Nasimi r.']
# 790 ['Yasamal r.', 'Yeni Yasamal q.']
# 791 ['Binaqadi r.', '8-ci mikrorayon q.']
# 792 ['Sabunchu r.', 'Bakixanov q.']
# 793 ['Narimanov r.']
# 794 ['Shah Ismayil Xatai m.', 'Xatai r.']
# 795 ['Inshaatchilar m.', 'Yasamal r.']
# 796 ['Nasimi r.']
# 797 ['Narimanov r.']
# 798 ['Ahmadli m.', 'Xatai r.']
# 799 ['Sabunchu r.', 'Nardaran q.']
# 800 ['Ichari Shahar m.', 'Yasamal r.']
# 802 ['Nariman Narimanov m.', 'Narimanov r.']
# 803 ['Yasamal r.', 'Yeni Yasamal q.']
# 804 ['20 Yanvar m.', 'Yasamal r.', 'Yasamal q.']
# 805 ['Qara Qarayev m.', 'Nizami r.']
# 806 ['20 Yanvar m.', 'Nasimi r.', '1-ci mikrorayon q.']
# 807 ['Qara Qarayev m.', 'Nizami r.']
# 808 ['Elmlar Akademiyasi m.', 'Yasamal r.', 'Yasamal q.']
# 809 ['Qara Qarayev m.', 'Nizami r.']
# 810 ['Narimanov r.']
# 811 ['Binaqadi r.', '9-cu mikrorayon q.']
# 812 ['Yasamal r.', 'Yeni Yasamal q.']
# 813 ['Sabail r.', 'Badamdar q.']
# 814 ['Nasimi r.']
# 815 ['Narimanov r.']
# 816 ['Binaqadi r.', '7-ci mikrorayon q.']
# 817 ['Memar Acami m.', 'Nasimi r.', '4-cu mikrorayon q.']
# 818 ['Sabunchu r.', 'Nardaran q.']
# 819 ['Sabunchu r.', 'Nardaran q.']
# 820 ['Sabunchu r.', 'Nardaran q.']
# 821 ['Sabunchu r.', 'Nardaran q.']
# 822 ['Ahmadli m.', 'Xatai r.', 'Ahmadli q.']
# 823 ['Nasimi r.']
# 825 ['Sabunchu r.', 'Nardaran q.']
# 826 ['Sabunchu r.', 'Nardaran q.']
# 827 ['Narimanov r.']
# 828 ['Nizami m.', 'Yasamal r.']
# 831 ['Sabunchu r.', 'Nardaran q.']
# 834 ['Sabunchu r.', 'Nardaran q.']
# 835 ['Sabunchu r.', 'Nardaran q.']
# 836 ['Sabunchu r.', 'Nardaran q.']
# 837 ['Nasimi r.']
# 838 ['20 Yanvar m.', 'Memar Acami m.', 'Nasimi r.']
# 840 ['Nasimi r.']
# 841 ['Nasimi m.', 'Binaqadi r.', '9-cu mikrorayon q.']
# 842 ['Qara Qarayev m.', 'Nizami r.', '8-ci kilometr q.']
# 843 ['Xatai r.', 'Hazi Aslanov q.']
# 844 ['Nasimi r.', '4-cu mikrorayon q.']
# 845 ['8 Noyabr m.', 'Nasimi r.']
# 846 ['Hazi Aslanov m.', 'Xatai r.']
# 847 ['Memar Acami m.', 'Nasimi r.', '4-cu mikrorayon q.']
# 848 ['Hazi Aslanov m.', 'Xatai r.']
# 849 ['Yasamal r.', 'Yasamal q.']
# 850 ['Xatai r.']
# 851 ['Ahmadli m.', 'Xatai r.']
# 852 ['Hazi Aslanov m.', 'Xatai r.']
# 854 ['Xazar r.', 'Bina q.']
# 855 ['Qara Qarayev m.', 'Nizami r.']
# 856 ['Binaqadi r.']
# 858 ['Hazi Aslanov m.', 'Xatai r.']
# 859 ['Nasimi r.']
# 860 ['Hazi Aslanov m.', 'Xatai r.']
# 861 ['Hazi Aslanov m.', 'Xatai r.', 'Hazi Aslanov q.']
# 862 ['Sabunchu r.', 'Bakixanov q.']
# 863 ['Hazi Aslanov m.', 'Xatai r.']
# 864 ['Elmlar Akademiyasi m.', 'Yasamal r.']
# 865 ['Memar Acami m.', 'Nasimi r.', '4-cu mikrorayon q.']
# 866 ['Neftchilar m.', 'Nizami r.']
# 867 ['Ahmadli m.', 'Xatai r.', 'Ahmadli q.']
# 868 ['Hazi Aslanov m.', 'Xatai r.']
# 869 ['Binaqadi r.', '9-cu mikrorayon q.']
# 870 ['Ahmadli m.', 'Xatai r.']
# 871 ['Yasamal r.', 'Yeni Yasamal q.']
# 872 ['Binaqadi r.']
# 873 ['Sabail r.']
# 874 ['Hazi Aslanov m.', 'Xatai r.']
# 875 ['8 Noyabr m.', 'Nasimi r.']
# 876 ['Hazi Aslanov m.', 'Xatai r.']
# 877 ['Nasimi r.']
# 878 ['Xatai r.']
# 879 ['Azadliq Prospekti m.', 'Binaqadi r.', '8-ci mikrorayon q.']
# 880 ['Yasamal r.']
# 881 ['Nasimi r.']
# 883 ['Nasimi r.']
# 884 ['Xatai r.', 'Ahmadli q.']
# 887 ['Narimanov r.']
# 888 ['28 May m.', 'Nasimi r.']
# 889 ['Sabail r.']
# 890 ['20 Yanvar m.', 'Memar Acami m.', 'Nasimi r.']
# 891 ['28 May m.', 'Nasimi r.']
# 892 ['Memar Acami m.', 'Nasimi r.', '3-cu mikrorayon q.']
# 893 ['Absheron r.', 'Masazir q.']
# 894 ['Nasimi r.']
# 895 ['Memar Acami m.', 'Binaqadi r.', '9-cu mikrorayon q.']
# 896 ['Memar Acami m.', 'Binaqadi r.', '9-cu mikrorayon q.']
# 897 ['Nasimi r.']
# 898 ['20 Yanvar m.', 'Memar Acami m.', 'Nasimi r.', '1-ci mikrorayon q.']
# 899 ['Nasimi r.']
# 900 ['Nasimi r.']
# 901 ['Nasimi r.']
# 902 ['Qara Qarayev m.', 'Nizami r.']
# 903 ['Yasamal r.']
# 904 ['8 Noyabr m.', 'Nasimi r.']
# 905 ['Hazi Aslanov m.', 'Xatai r.']
# 906 ['Shah Ismayil Xatai m.', 'Xatai r.']
# 907 ['Shah Ismayil Xatai m.', 'Xatai r.']
# 908 ['Absheron r.', 'Masazir q.']
# 910 ['Xatai r.']
# 912 ['Binaqadi r.', '7-ci mikrorayon q.']
# 914 ['Inshaatchilar m.', 'Yasamal r.']
# 915 ['20 Yanvar m.', 'Yasamal r.']
# 916 ['Qara Qarayev m.', 'Nizami r.']
# 917 ['Nasimi r.', 'Kubinka q.']
# 918 ['Elmlar Akademiyasi m.', 'Yasamal r.']
# 919 ['Elmlar Akademiyasi m.', 'Yasamal r.', 'Yasamal q.']
# 920 ['Ichari Shahar m.', 'Sabail r.']
# 921 ['Elmlar Akademiyasi m.', 'Yasamal r.']
# 922 ['Yasamal r.']
# 923 ['Shah Ismayil Xatai m.', 'Xatai r.']
# 925 ['Nasimi r.']
# 926 ['Xatai r.', 'Hazi Aslanov q.']
# 927 ['20 Yanvar m.', 'Yasamal r.']
# 928 ['Xatai r.']
# 929 ['Nasimi r.']
# 930 ['Ganclik m.', 'Narimanov r.']
# 931 ['Hazi Aslanov m.', 'Xatai r.']
# 932 ['Elmlar Akademiyasi m.', 'Yasamal r.']
# 933 ['Qara Qarayev m.', 'Nizami r.']
# 934 ['Nasimi r.']
# 935 ['Nizami r.', '8-ci kilometr q.']
# 936 ['Sabail r.', 'Bayil q.']
# 937 ['Binaqadi r.', '7-ci mikrorayon q.']
# 940 ['Yasamal r.', 'Yasamal q.']
# 942 ['Xatai r.', 'Ahmadli q.']
# 943 ['Memar Acami m.', 'Binaqadi r.', '9-cu mikrorayon q.']
# 944 ['Inshaatchilar m.', 'Yasamal r.', 'Yasamal q.']
# 945 ['Nasimi r.']
# 946 ['Narimanov r.']
# 947 ['Elmlar Akademiyasi m.', 'Yasamal r.']
# 948 ['8 Noyabr m.', 'Nasimi r.']
# 949 ['Elmlar Akademiyasi m.', 'Yasamal r.']
# 950 ['Nizami r.']
# 951 ['Yasamal r.']
# 952 ['8 Noyabr m.', 'Nasimi r.']
# 953 ['Nasimi r.']
# 954 ['Nizami r.']
# 955 ['Shah Ismayil Xatai m.', 'Xatai r.']
# 956 ['Xalqlar Dostlugu m.', 'Nizami r.']
# 957 ['Yasamal r.']
# 958 ['Nasimi r.']
# 959 ['Nasimi r.']
# 960 ['Sabail r.', 'Badamdar q.']
# 961 ['20 Yanvar m.', 'Memar Acami m.', 'Nasimi r.', '5-ci mikrorayon q.']
# 962 ['Binaqadi r.']
# 963 ['Inshaatchilar m.', 'Yasamal r.', 'Yeni Yasamal q.']
# 964 ['Sabunchu r.', 'Nardaran q.']
# 967 ['Absheron r.', 'Masazir q.']
# 968 ['Narimanov r.']
# 970 ['Yasamal r.', 'Yeni Yasamal q.']
# 971 ['Binaqadi r.', 'M.A.Rasulzada q.']
# 972 ['Suraxani r.', 'Yeni Gunashli q.']
# 973 ['Shah Ismayil Xatai m.', 'Xatai r.']
# 974 ['Narimanov r.']
# 975 ['Suraxani r.', 'Amircan q.']
# 976 ['Ahmadli m.', 'Hazi Aslanov m.', 'Xatai r.', 'Ahmadli q.']
# 977 ['Yasamal r.', 'Yeni Yasamal q.']
# 978 ['Nariman Narimanov m.', 'Narimanov r.']
# 979 ['Binaqadi r.', '7-ci mikrorayon q.']
# 980 ['Yasamal r.', 'Yeni Yasamal q.']
# 981 ['Nariman Narimanov m.', 'Narimanov r.']
# 983 ['Binaqadi r.', '7-ci mikrorayon q.']
# 984 ['Yasamal r.', 'Yeni Yasamal q.']
# 985 ['Xatai r.', 'Ahmadli q.']
# 986 ['Xatai r.']
# 987 ['Nizami m.', 'Yasamal r.']
# 988 ['Memar Acami m.', 'Nasimi r.', '4-cu mikrorayon q.']
# 989 ['Elmlar Akademiyasi m.', 'Yasamal r.', 'Yasamal q.']
# 990 ['Sabunchu r.', 'Bakixanov q.']
# 991 ['Xatai r.', 'Hazi Aslanov q.']
# 992 ['Hazi Aslanov m.', 'Ahmadli m.', 'Xatai r.', 'Hazi Aslanov q.']
# 993 ['Binaqadi r.', '8-ci mikrorayon q.']
# 994 ['Sabail r.', 'Bayil q.']
# 999 ['Nasimi r.']
# 1000 ['Nizami r.']
# 1001 ['Sabail r.', 'Badamdar q.']
# 1002 ['Xalqlar Dostlugu m.', 'Nizami r.', '8-ci kilometr q.']
# 1003 ['Memar Acami m.', 'Nasimi r.']
# 1004 ['20 Yanvar m.', 'Yasamal r.', 'Yasamal q.']
# 1005 ['Nasimi r.']
# 1006 ['Narimanov r.']
# 1007 ['Nasimi r.']
# 1008 ['Binaqadi r.', '7-ci mikrorayon q.']
# 1009 ['Qara Qarayev m.', 'Nizami r.']
# 1010 ['Nasimi r.']
# 1011 ['Nizami m.', 'Nasimi r.']
# 1012 ['Narimanov r.']
# 1013 ['Nariman Narimanov m.', 'Narimanov r.']
# 1014 ['Nasimi r.']
# 1015 ['Nariman Narimanov m.', 'Narimanov r.']
# 1016 ['Nasimi r.']
# 1017 ['Narimanov r.']
# 1018 ['Nasimi r.']
# 1019 ['Ahmadli m.', 'Xatai r.', 'Ahmadli q.']
# 1020 ['Xatai r.']
# 1021 ['Nasimi r.']
# 1023 ['Inshaatchilar m.', 'Yasamal r.']
# 1025 ['Xatai r.']
# 1026 ['Xatai r.', 'Ahmadli q.']
# 1027 ['Azadliq Prospekti m.', 'Binaqadi r.']
# 1028 ['Hazi Aslanov m.', 'Xatai r.']
# 1029 ['28 May m.', 'Nasimi r.']
# 1030 ['Xatai r.', 'Ag shahar q.']
# 1031 ['Hazi Aslanov m.', 'Ahmadli m.', 'Xatai r.', 'Ahmadli q.']
# 1032 ['Sabunchu r.', 'Bakixanov q.']
# 1033 ['Binaqadi r.', '8-ci mikrorayon q.']
# 1034 ['Nizami r.']
# 1035 ['Yasamal r.']
# 1036 ['Elmlar Akademiyasi m.', 'Yasamal r.', 'Yasamal q.']
# 1037 ['8 Noyabr m.', 'Nasimi r.']
# 1038 ['Absheron r.', 'Masazir q.']
# 1039 ['20 Yanvar m.', 'Yasamal r.']
# 1040 ['Ganclik m.', 'Narimanov r.']
# 1041 ['Qara Qarayev m.', 'Nizami r.', '8-ci kilometr q.']
# 1042 ['Memar Acami m.', 'Nasimi r.']
# 1043 ['Nizami m.', 'Nasimi r.', 'Kubinka q.']
# 1044 ['Yasamal r.']
# 1045 ['Xatai r.', 'Hazi Aslanov q.']
# 1046 ['Ganclik m.', 'Narimanov r.']
# 1047 ['Binaqadi r.', '9-cu mikrorayon q.']
# 1048 ['Nasimi m.', 'Binaqadi r.', '6-ci mikrorayon q.']
# 1049 ['Binaqadi r.']
# 1050 ['Nasimi r.']
# 1051 ['Nizami m.', 'Yasamal r.']
# 1053 ['Yasamal r.', 'Yeni Yasamal q.']
# 1054 ['Binaqadi r.', 'Sulutapa q.']
# 1055 ['Suraxani r.', 'Yeni Gunashli q.']
# 1057 ['Xalqlar Dostlugu m.', 'Xatai r.']
# 1058 ['Sabail r.']
# 1059 ['Qara Qarayev m.', 'Nizami r.', '8-ci kilometr q.']
# 1060 ['Hazi Aslanov m.', 'Ahmadli m.', 'Xatai r.', 'Ahmadli q.']
# 1061 ['Suraxani r.', 'Yeni Gunashli q.']
# 1062 ['Avtovagzal m.', 'Binaqadi r.', 'Bilacari q.']
# 1063 ['Binaqadi r.', '9-cu mikrorayon q.']
# 1064 ['Yasamal r.', 'Yeni Yasamal q.']
# 1065 ['Nizami m.', 'Nasimi r.']
# 1066 ['Absheron r.', 'Masazir q.']
# 1067 ['Inshaatchilar m.', 'Yasamal r.']
# 1068 ['Inshaatchilar m.', 'Yasamal r.']
# 1069 ['Nariman Narimanov m.', 'Narimanov r.']
# 1070 ['Yasamal r.', 'Yeni Yasamal q.']
# 1071 ['Inshaatchilar m.', 'Yasamal r.', 'Yasamal q.']
# 1072 ['Yasamal r.', 'Yeni Yasamal q.']
# 1073 ['Shah Ismayil Xatai m.', 'Xatai r.']
# 1074 ['Yasamal r.', 'Yeni Yasamal q.']
# 1075 ['Yasamal r.', 'Yeni Yasamal q.']
# 1076 ['28 May m.', 'Nasimi r.']
# 1078 ['Qara Qarayev m.', 'Nizami r.']
# 1079 ['Ganclik m.', 'Narimanov r.']
# 1081 ['Binaqadi r.', '7-ci mikrorayon q.']
# 1082 ['Nasimi r.']
# 1083 ['Binaqadi r.', '7-ci mikrorayon q.']
# 1084 ['Binaqadi r.', '8-ci mikrorayon q.']
# 1085 ['Sabail r.']
# 1086 ['Inshaatchilar m.', 'Yasamal r.', 'Yasamal q.']
# 1087 ['Nasimi r.', '3-cu mikrorayon q.']
# 1088 ['Shah Ismayil Xatai m.', 'Xatai r.']
# 1089 ['20 Yanvar m.', 'Yasamal r.']
# 1090 ['Nasimi r.']
# 1091 ['Absheron r.', 'Masazir q.']
# 1092 ['Xatai r.']
# 1094 ['Darnagul m.', 'Narimanov r.']
# 1095 ['Nasimi r.']
# 1096 ['Nasimi r.']
# 1097 ['Elmlar Akademiyasi m.', 'Yasamal r.', 'Yasamal q.']
# 1098 ['Binaqadi r.', '7-ci mikrorayon q.']
# 1099 ['Elmlar Akademiyasi m.', 'Yasamal r.', 'Yasamal q.']
# 1100 ['20 Yanvar m.', 'Nasimi r.', '1-ci mikrorayon q.']
# 1101 ['Yasamal r.', 'Yeni Yasamal q.']
# 1102 ['Suraxani r.', 'Yeni Gunashli q.']
# 1103 ['Nasimi r.']
# 1104 ['Sabail r.', 'Bayil q.']
# 1106 ['Shah Ismayil Xatai m.', 'Xatai r.']
# 1110 ['Yasamal r.', 'Yeni Yasamal q.']
# 1111 ['Nasimi r.']
# 1112 ['Narimanov r.']
# 1113 ['Narimanov r.']
# 1114 ['Inshaatchilar m.', 'Yasamal r.', 'Yasamal q.']
# 1115 ['Yasamal r.', 'Yeni Yasamal q.']
# 1116 ['Sabunchu r.', 'Sabunchu q.']
# 1117 ['Hazi Aslanov m.', 'Xatai r.']
# 1118 ['Binaqadi r.', '7-ci mikrorayon q.']
# 1119 ['Yasamal r.', 'Yeni Yasamal q.']
# 1120 ['8 Noyabr m.', 'Nasimi r.']
# 1121 ['Nariman Narimanov m.', 'Narimanov r.']
# 1122 ['Qara Qarayev m.', 'Nizami r.', '8-ci kilometr q.']
# 1123 ['Nariman Narimanov m.', 'Narimanov r.']
# 1124 ['Narimanov r.']
# 1125 ['Nariman Narimanov m.', 'Narimanov r.']
# 1126 ['Narimanov r.']
# 1127 ['Nariman Narimanov m.', 'Narimanov r.']
# 1128 ['Nasimi r.']
# 1129 ['Narimanov r.']
# 1130 ['Memar Acami m.', 'Binaqadi r.', '9-cu mikrorayon q.']
# 1131 ['8 Noyabr m.', 'Nasimi r.']
# 1132 ['28 May m.', 'Nasimi r.']
# 1133 ['Absheron r.', 'Masazir q.']
# 1134 ['Nasimi r.']
# 1138 ['Narimanov r.']
# 1139 ['Memar Acami m.', 'Binaqadi r.', '9-cu mikrorayon q.']
# 1140 ['Narimanov r.']
# 1141 ['Shah Ismayil Xatai m.', 'Xatai r.']
# 1142 ['Narimanov r.']
# 1143 ['Absheron r.', 'Masazir q.']
# 1144 ['Yasamal r.', 'Yeni Yasamal q.']
# 1145 ['Xatai r.', 'Hazi Aslanov q.']
# 1146 ['20 Yanvar m.', 'Nasimi r.', '1-ci mikrorayon q.']
# 1147 ['Nasimi r.']
# 1148 ['Xatai r.', 'Ahmadli q.']
# 1149 ['Narimanov r.']
# 1150 ['Azadliq Prospekti m.', 'Binaqadi r.']
# 1151 ['Nasimi m.', 'Binaqadi r.', '6-ci mikrorayon q.']
# 1152 ['Nariman Narimanov m.', 'Narimanov r.']
# 1153 ['Narimanov r.']
# 1154 ['Nariman Narimanov m.', 'Narimanov r.']
# 1155 ['Elmlar Akademiyasi m.', 'Yasamal r.']
# 1156 ['28 May m.', 'Nasimi r.']
# 1157 ['Nasimi r.']
# 1160 ['Yasamal r.']
# 1162 ['Elmlar Akademiyasi m.', 'Yasamal r.', 'Yasamal q.']
# 1163 ['Elmlar Akademiyasi m.', 'Yasamal r.']
# 1165 ['Binaqadi r.', '8-ci mikrorayon q.']
# 1166 ['Inshaatchilar m.', 'Yasamal r.']
# 1167 ['Elmlar Akademiyasi m.', 'Yasamal r.']
# 1168 ['Ganclik m.', 'Narimanov r.']
# 1169 ['Elmlar Akademiyasi m.', 'Yasamal r.']
# 1170 ['Binaqadi r.', '8-ci mikrorayon q.']
# 1171 ['Suraxani r.', 'Hovsan q.']
# 1172 ['Ganclik m.', 'Narimanov r.']
# 1173 ['Nasimi r.']
# 1174 ['Inshaatchilar m.', 'Yasamal r.']
# 1175 ['Sabail r.', 'Badamdar q.']
# 1176 ['Elmlar Akademiyasi m.', 'Yasamal r.']
# 1178 ['Nasimi r.']
# 1179 ['28 May m.', 'Sahil m.', 'Nasimi r.']
# 1180 ['28 May m.', 'Nasimi r.']
# 1181 ['28 May m.', 'Nasimi r.']
# 1182 ['28 May m.', 'Sabail r.']
# 1183 ['Hazi Aslanov m.', 'Xatai r.', 'Hazi Aslanov q.']
# 1184 ['Sabunchu r.', 'Bakixanov q.']
# 1186 ['Binaqadi r.', 'Binaqadi q.']
# 1189 ['Nasimi r.']
# 1190 ['Elmlar Akademiyasi m.', 'Yasamal r.']
# 1191 ['Sabunchu r.', 'Bakixanov q.']
# 1193 ['Sabunchu r.', 'Ramana q.']
# 1194 ['Nasimi r.']
# 1195 ['Absheron r.', 'Masazir q.']
# 1196 ['Sabail r.']
# 1197 ['Memar Acami m.', 'Nasimi r.']
# 1198 ['Ahmadli m.', 'Xatai r.', 'Ahmadli q.']
# 1199 ['Qara Qarayev m.', 'Nizami r.', '8-ci kilometr q.']
# 1200 ['Nasimi r.']
# 1201 ['Sabail r.', 'Bayil q.']
# 1202 ['Sahil m.', 'Nasimi r.']
# 1203 ['Memar Acami m.', 'Nasimi r.', '4-cu mikrorayon q.']
# 1204 ['Inshaatchilar m.', 'Yasamal r.', 'Yasamal q.']
# 1206 ['Yasamal r.', 'Yeni Yasamal q.']
# 1207 ['Binaqadi r.', '7-ci mikrorayon q.']
# 1208 ['Binaqadi r.', '7-ci mikrorayon q.']
# 1209 ['Binaqadi r.', '7-ci mikrorayon q.']
# 1211 ['Inshaatchilar m.', 'Yasamal r.', 'Yasamal q.']
# 1212 ['Yasamal r.', 'Yasamal q.']
# 1213 ['Xatai r.', 'Ahmadli q.']
# 1214 ['Inshaatchilar m.', 'Yasamal r.']
# 1215 ['Binaqadi r.', 'M.A.Rasulzada q.']
# 1220 ['Nizami r.']
# 1221 ['Hazi Aslanov m.', 'Xatai r.', 'Ahmadli q.']
# 1222 ['Xalqlar Dostlugu m.', 'Nizami r.', '8-ci kilometr q.']
# 1223 ['Qaradag r.', 'Sahil q.']
# 1224 ['Xatai r.', 'Hazi Aslanov q.']
# 1225 ['Yasamal r.', 'Yeni Yasamal q.']
# 1226 ['Hazi Aslanov m.', 'Xatai r.', 'Ahmadli q.']
# 1227 ['Narimanov r.']
# 1228 ['Narimanov r.']
# 1229 ['Nariman Narimanov m.', 'Narimanov r.']
# 1230 ['Narimanov r.']
# 1231 ['Yasamal r.', 'Yasamal q.']
# 1232 ['Memar Acami m.', 'Nasimi r.', '4-cu mikrorayon q.']
# 1233 ['Memar Acami m.', 'Nasimi r.', '4-cu mikrorayon q.']
# 1234 ['Inshaatchilar m.', 'Yasamal r.', 'Yasamal q.']
# 1235 ['Hazi Aslanov m.', 'Xatai r.', 'Ahmadli q.']
# 1236 ['Darnagul m.', 'Narimanov r.']
# 1237 ['Hazi Aslanov m.', 'Xatai r.', 'Ahmadli q.']
# 1238 ['Sabail r.', 'Badamdar q.']
# 1239 ['Shah Ismayil Xatai m.', 'Xatai r.']
# 1240 ['Nariman Narimanov m.', 'Narimanov r.']
# 1241 ['Neftchilar m.', 'Nizami r.']
# 1242 ['Narimanov r.']
# 1244 ['Elmlar Akademiyasi m.', 'Yasamal r.']
# 1246 ['Ahmadli m.', 'Hazi Aslanov m.', 'Xatai r.']
# 1247 ['Nizami r.']
# 1248 ['Neftchilar m.', 'Nizami r.']
# 1249 ['Ahmadli m.', 'Xatai r.']
# 1250 ['Nizami m.', 'Nasimi r.']
# 1251 ['Yasamal r.']
# 1253 ['Yasamal r.']
# 1254 ['20 Yanvar m.', 'Memar Acami m.', 'Nasimi r.']
# 1255 ['Narimanov r.']
# 1256 ['Binaqadi r.', 'Bilacari q.']
# 1257 ['Azadliq Prospekti m.', 'Binaqadi r.', '8-ci mikrorayon q.']
# 1258 ['20 Yanvar m.', 'Yasamal r.']
# 1259 ['Ahmadli m.', 'Xatai r.']
# 1260 ['Elmlar Akademiyasi m.', 'Yasamal r.']
# 1261 ['Memar Acami m.', 'Nasimi r.']
# 1262 ['Binaqadi r.', 'Xutor q.']
# 1263 ['Nasimi m.', 'Binaqadi r.', '6-ci mikrorayon q.']
# 1264 ['Nasimi m.', 'Binaqadi r.']
# 1265 ['Yasamal r.']
# 1266 ['Sabunchu r.', 'Bakixanov q.']
# 1267 ['Azadliq Prospekti m.', 'Binaqadi r.']
# 1269 ['28 May m.', 'Nasimi r.']
# 1270 ['Ahmadli m.', 'Hazi Aslanov m.', 'Xatai r.', 'Ahmadli q.']
# 1271 ['Shah Ismayil Xatai m.', 'Xatai r.']
# 1272 ['Ichari Shahar m.', 'Sabail r.']
# 1274 ['Narimanov r.']
# 1275 ['Narimanov r.']
# 1276 ['28 May m.', 'Nasimi r.']
# 1277 ['28 May m.', 'Nasimi r.']
# 1278 ['Nasimi r.']
# 1279 ['Nasimi r.']
# 1280 ['Yasamal r.']
# 1281 ['Suraxani r.', 'Hovsan q.']
# 1283 ['Yasamal r.']
# 1284 ['Nariman Narimanov m.', 'Narimanov r.']
# 1285 ['Narimanov r.']
# 1286 ['Xalqlar Dostlugu m.', 'Xatai r.', 'Ahmadli q.']
# 1287 ['Inshaatchilar m.', 'Yasamal r.']
# 1288 ['Yasamal r.']
# 1289 ['Inshaatchilar m.', 'Yasamal r.']
# 1290 ['Binaqadi r.', '9-cu mikrorayon q.']
# 1291 ['Nasimi r.']
# 1292 ['Yasamal r.', 'Yeni Yasamal q.']
# 1293 ['Azadliq Prospekti m.', 'Binaqadi r.', '7-ci mikrorayon q.']
# 1294 ['Sabunchu r.', 'Bakixanov q.']
# 1295 ['Darnagul m.', 'Binaqadi r.', '7-ci mikrorayon q.']
# 1296 ['Binaqadi r.', '9-cu mikrorayon q.']
# 1297 ['28 May m.', 'Sahil m.', 'Nasimi r.']
# 1299 ['Narimanov r.', 'Nariman Narimanov m.']
# 1300 ['Nariman Narimanov m.', 'Narimanov r.']
# 1303 ['Yasamal r.', 'Yeni Yasamal q.']
# 1305 ['Shah Ismayil Xatai m.', 'Xatai r.', 'Ag shahar q.']
# 1306 ['Elmlar Akademiyasi m.', 'Yasamal r.', 'Yasamal q.']
# 1307 ['Qaradag r.', 'Lokbatan q.']
# 1308 ['Binaqadi r.', 'Xocasan q.']
# 1309 ['Qara Qarayev m.', 'Nizami r.']
# 1310 ['Ahmadli m.', 'Xatai r.', 'Ahmadli q.']
# 1311 ['Hazi Aslanov m.', 'Xatai r.']
# 1312 ['Azadliq Prospekti m.', 'Binaqadi r.', '8-ci mikrorayon q.']
# 1313 ['Sabail r.', 'Bayil q.']
# 1314 ['Absheron r.', 'Masazir q.']
# 1315 ['Binaqadi r.', '8-ci mikrorayon q.']
# 1316 ['Hazi Aslanov m.', 'Xatai r.', 'Hazi Aslanov q.']
# 1317 ['Yasamal r.', 'Yeni Yasamal q.']
# 1318 ['28 May m.', 'Nasimi r.']
# 1319 ['Nasimi r.']
# 1320 ['Nasimi r.']
# 1321 ['Narimanov r.']
# 1322 ['Nasimi m.', 'Binaqadi r.', '6-ci mikrorayon q.']
# 1323 ['Qara Qarayev m.', 'Nizami r.', '8-ci kilometr q.']
# 1324 ['Narimanov r.']
# 1325 ['Xatai r.']
# 1326 ['Nasimi r.']
# 1327 ['Sabail r.']
# 1329 ['Nizami m.', 'Yasamal r.']
# 1330 ['Nasimi m.', 'Binaqadi r.', '6-ci mikrorayon q.']
# 1331 ['Absheron r.', 'Saray q.']
# 1332 ['Xalqlar Dostlugu m.', 'Nizami r.']
# 1333 ['Yasamal r.', 'Yeni Yasamal q.']
# 1334 ['Yasamal r.', 'Yeni Yasamal q.']
# 1335 ['Narimanov r.']
# 1336 ['Nasimi r.', '4-cu mikrorayon q.']
# 1337 ['Nariman Narimanov m.', 'Narimanov r.']
# 1338 ['Yasamal r.', 'Yeni Yasamal q.']
# 1339 ['Nariman Narimanov m.', 'Narimanov r.']
# 1340 ['20 Yanvar m.', 'Nasimi r.', '1-ci mikrorayon q.']
# 1341 ['Nasimi r.']
# 1342 ['Binaqadi r.', '7-ci mikrorayon q.']
# 1343 ['Qaradag r.', 'Lokbatan q.']
# 1344 ['Memar Acami m.', 'Nasimi r.', '4-cu mikrorayon q.']
# 1345 ['Sabail r.']
# 1346 ['Sabail r.', 'Bayil q.']
# 1347 ['Suraxani r.', 'Qarachuxur q.']
# 1348 ['Xatai r.']
# 1349 ['Narimanov r.']
# 1350 ['Narimanov r.']
# 1351 ['Nizami m.', 'Yasamal r.']
# 1352 ['Binaqadi r.', '8-ci mikrorayon q.']
# 1353 ['Elmlar Akademiyasi m.', 'Yasamal r.']
# 1354 ['Ahmadli m.', 'Xatai r.']
# 1355 ['Ganclik m.', 'Narimanov r.']
# 1356 ['Ganclik m.', 'Narimanov r.']
# 1358 ['Nasimi r.']
# 1359 ['Inshaatchilar m.', 'Yasamal r.']
# 1360 ['Narimanov r.']
# 1361 ['Narimanov r.']
# 1362 ['Narimanov r.']
# 1363 ['Nasimi m.', 'Binaqadi r.']
# 1364 ['Binaqadi r.', '9-cu mikrorayon q.']
# 1365 ['Azadliq Prospekti m.', 'Binaqadi r.']
# 1366 ['20 Yanvar m.', 'Nasimi r.']
# 1367 ['Xatai r.']
# 1368 ['Yasamal r.', 'Yeni Yasamal q.']
# 1369 ['28 May m.', 'Narimanov r.']
# 1370 ['Absheron r.', 'Masazir q.']
# 1371 ['Memar Acami m.', 'Nasimi r.']
# 1372 ['Nasimi r.']
# 1373 ['Inshaatchilar m.', 'Yasamal r.']
# 1374 ['Nasimi r.']
# 1375 ['Nariman Narimanov m.', 'Narimanov r.']
# 1376 ['Absheron r.']
# 1377 ['Yasamal r.']
# 1378 ['Nasimi r.']
# 1379 ['Yasamal r.']
# 1380 ['Xalqlar Dostlugu m.', 'Nizami r.']
# 1381 ['Sahil m.', 'Nasimi r.']
# 1385 ['Inshaatchilar m.', 'Yasamal r.']
# 1386 ['Nizami r.']
# 1387 ['Xalqlar Dostlugu m.', 'Nizami r.']
# 1388 ['Xatai r.', 'Ag shahar q.']
# 1389 ['Shah Ismayil Xatai m.', 'Xatai r.']
# 1390 ['Xalqlar Dostlugu m.', 'Nizami r.']
# 1391 ['Qara Qarayev m.', 'Nizami r.']
# 1392 ['Sabail r.', 'Badamdar q.']
# 1393 ['Qara Qarayev m.', 'Nizami r.', '8-ci kilometr q.']
# 1394 ['Nizami r.']
# 1395 ['Qara Qarayev m.', 'Nizami r.']
# 1396 ['Narimanov r.']
# 1397 ['Nasimi r.']
# 1398 ['Nasimi r.']
# 1399 ['Nasimi r.']
# 1400 ['Sahil m.', 'Ichari Shahar m.', 'Sabail r.']
# 1401 ['Nasimi m.', 'Binaqadi r.', '6-ci mikrorayon q.']
# 1402 ['Sabail r.']
# 1403 ['Narimanov r.']
# 1404 ['Memar Acami m.', 'Nasimi r.', '4-cu mikrorayon q.']
# 1405 ['Narimanov r.']
# 1406 ['Yasamal r.']
# 1407 ['Nasimi r.']
# 1408 ['Nasimi r.']
# 1409 ['Nasimi r.']
# 1411 ['Yasamal r.', 'Yasamal q.']
# 1412 ['Sabunchu r.', 'Bakixanov q.']
# 1413 ['Sabail r.', 'Bayil q.']
# 1414 ['Nasimi r.']
# 1415 ['Nasimi r.']
# 1416 ['Narimanov r.']
# 1417 ['Narimanov r.']
# 1418 ['Memar Acami m.', 'Nasimi r.']
# 1419 ['Nasimi r.']
# 1420 ['Absheron r.', 'Masazir q.']
# 1421 ['8 Noyabr m.', 'Nasimi r.']
# 1422 ['Ganclik m.', 'Narimanov r.']
# 1423 ['Elmlar Akademiyasi m.', 'Yasamal r.']
# 1424 ['Shah Ismayil Xatai m.', 'Xatai r.']
# 1425 ['Nasimi r.']
# 1426 ['Memar Acami m.', 'Nasimi r.', '3-cu mikrorayon q.']
# 1427 ['Narimanov r.']
# 1428 ['Nasimi r.']
# 1429 ['Narimanov r.']
# 1430 ['Nasimi r.']
# 1431 ['Nizami m.', 'Yasamal r.']
# 1432 ['Nasimi r.']
# 1433 ['Nasimi r.']
# 1434 ['Narimanov r.']
# 1435 ['Sabail r.', 'Badamdar q.']
# 1436 ['Narimanov r.']
# 1437 ['Nasimi r.']
# 1440 ['Narimanov r.']
# 1441 ['Inshaatchilar m.', 'Yasamal r.', 'Yasamal q.']
# 1442 ['Narimanov r.']
# 1443 ['Ganclik m.', 'Narimanov r.']
# 1444 ['Nariman Narimanov m.', 'Narimanov r.']
# 1445 ['Nizami m.', 'Nasimi r.', 'Kubinka q.']
# 1446 ['Xatai r.']
# 1447 ['Memar Acami m.', 'Nasimi r.']
# 1448 ['Yasamal r.', 'Yeni Yasamal q.']
# 1449 ['Narimanov r.']
# 1450 ['Memar Acami m.', 'Nasimi r.', '4-cu mikrorayon q.']
# 1451 ['Narimanov r.']
# 1452 ['Elmlar Akademiyasi m.', 'Yasamal r.']
# 1453 ['Nariman Narimanov m.', 'Narimanov r.']
# 1454 ['Ganclik m.', 'Narimanov r.']
# 1455 ['8 Noyabr m.', 'Narimanov r.']
# 1456 ['Nasimi m.', 'Binaqadi r.', 'M.A.Rasulzada q.']
# 1457 ['Sabail r.']
# 1458 ['Sabunchu r.', 'Bakixanov q.']
# 1459 ['Sabail r.', 'Badamdar q.']
# 1460 ['Binaqadi r.', '9-cu mikrorayon q.']
# 1461 ['28 May m.', 'Nasimi r.']
# 1462 ['Nasimi r.']
# 1463 ['Neftchilar m.', 'Nizami r.', '8-ci kilometr q.']
# 1464 ['Xalqlar Dostlugu m.', 'Xatai r.']
# 1465 ['Ahmadli m.', 'Xatai r.']
# 1468 ['Ichari Shahar m.', 'Sabail r.']
# 1470 ['Elmlar Akademiyasi m.', 'Yasamal r.']
# 1471 ['Sahil m.', 'Ichari Shahar m.', 'Sabail r.']
# 1472 ['Absheron r.', 'Masazir q.']
# 1473 ['Nasimi r.', '3-cu mikrorayon q.']
# 1474 ['Xatai r.']
# 1475 ['8 Noyabr m.', 'Nasimi r.']
# ...
# 27310 ['Shah Ismayil Xatai m.', 'Xatai r.']
# 27311 ['Nasimi m.', 'Nasimi r.']
# 27312 ['Narimanov r.']
# 27313 ['Shah Ismayil Xatai m.', 'Xatai r.']
# 27314 ['Narimanov r.']
# 27315 ['Nasimi r.']
# 27316 ['Nariman Narimanov m.', 'Narimanov r.']
# 27321 ['Nizami m.', 'Yasamal r.']
# 27322 ['Nariman Narimanov m.', 'Narimanov r.']
# 27323 ['8 Noyabr m.', 'Nasimi r.']
# 27324 ['Yasamal r.', 'Yeni Yasamal q.']
# 27325 ['Xalqlar Dostlugu m.', 'Nizami r.']
# 27326 ['Qara Qarayev m.', 'Nizami r.']
# 27327 ['Inshaatchilar m.', 'Yasamal r.', 'Yasamal q.']
# 27328 ['Ahmadli m.', 'Xatai r.', 'Ahmadli q.']
# 27329 ['Nizami m.', 'Nasimi r.']
# 27330 ['Sabunchu r.', 'Bakixanov q.']
# 27331 ['Shah Ismayil Xatai m.', 'Xatai r.']
# 27332 ['Sabunchu r.', 'Bakixanov q.']
# 27333 ['Sabunchu r.', 'Bakixanov q.']
# 27334 ['Sabunchu r.', 'Bakixanov q.']
# 27335 ['Narimanov r.']
# 27336 ['Yasamal r.']
# 27337 ['Qara Qarayev m.', 'Nizami r.']
# 27338 ['Sahil m.', 'Sabail r.']
# 27339 ['Ahmadli m.', 'Xatai r.', 'Ahmadli q.']
# 27340 ['Xatai r.']
# 27341 ['Neftchilar m.', 'Xalqlar Dostlugu m.', 'Nizami r.', '8-ci kilometr q.']
# 27342 ['Nariman Narimanov m.', 'Narimanov r.']
# 27343 ['Ganclik m.', 'Narimanov r.']
# 27344 ['Nizami m.', 'Yasamal r.']
# 27349 ['Memar Acami m.', 'Nasimi r.']
# 27350 ['Absheron r.']
# 27351 ['Ahmadli m.', 'Xatai r.', 'Ahmadli q.']
# 27352 ['Nariman Narimanov m.', 'Narimanov r.']
# 27353 ['Suraxani r.', 'Yeni Gunashli q.']
# 27354 ['Xatai r.', 'Hazi Aslanov q.']
# 27355 ['Qara Qarayev m.', 'Nizami r.']
# 27356 ['Xazar r.', 'Bina q.']
# 27357 ['Narimanov r.']
# 27358 ['Nariman Narimanov m.', 'Narimanov r.']
# 27359 ['Xazar r.']
# 27360 ['Memar Acami m.', 'Nasimi r.']
# 27361 ['Xatai r.', 'Ag shahar q.']
# 27362 ['Nasimi r.']
# 27363 ['Shah Ismayil Xatai m.', 'Xatai r.']
# 27364 ['Yasamal r.']
# 27365 ['Elmlar Akademiyasi m.', 'Yasamal r.']
# 27366 ['Elmlar Akademiyasi m.', 'Yasamal r.']
# 27367 ['Nizami m.', 'Yasamal r.']
# 27368 ['Ahmadli m.', 'Xatai r.']
# 27369 ['Azadliq Prospekti m.', 'Binaqadi r.', '7-ci mikrorayon q.']
# 27370 ['Absheron r.']
# 27371 ['Yasamal r.']
# 27372 ['Inshaatchilar m.', 'Yasamal r.']
# 27377 ['Xatai r.']
# 27378 ['Narimanov r.']
# 27380 ['Hazi Aslanov m.', 'Xatai r.', 'Ahmadli q.']
# 27381 ['Elmlar Akademiyasi m.', 'Nizami m.', 'Yasamal r.']
# 27382 ['Nizami m.', 'Yasamal r.']
# 27383 ['Hazi Aslanov m.', 'Xatai r.']
# 27384 ['Xatai r.']
# 27385 ['Ichari Shahar m.', 'Sabail r.']
# 27386 ['Xalqlar Dostlugu m.', 'Nizami r.']
# 27387 ['Ichari Shahar m.', 'Sabail r.']
# 27388 ['Sabunchu r.', 'Bakixanov q.']
# 27389 ['Xatai r.']
# 27390 ['Shah Ismayil Xatai m.', 'Xatai r.']
# 27391 ['Inshaatchilar m.', 'Yasamal r.']
# 27392 ['Inshaatchilar m.', 'Yasamal r.']
# 27393 ['Yasamal r.', 'Yeni Yasamal q.']
# 27394 ['Xatai r.']
# 27395 ['28 May m.', 'Nasimi r.']
# 27396 ['Nizami m.', 'Yasamal r.']
# 27397 ['Shah Ismayil Xatai m.', 'Xatai r.']
# 27398 ['Xatai r.', 'Hazi Aslanov q.']
# 27399 ['Nizami r.']
# 27400 ['Elmlar Akademiyasi m.', 'Yasamal r.']
# 27405 ['Nasimi r.']
# 27406 ['Narimanov r.']
# 27407 ['Yasamal r.', 'Yeni Yasamal q.']
# 27408 ['Xatai r.']
# 27409 ['Inshaatchilar m.', 'Yasamal r.']
# 27410 ['Xalqlar Dostlugu m.', 'Nizami r.']
# 27411 ['Binaqadi r.', '9-cu mikrorayon q.']
# 27412 ['Shah Ismayil Xatai m.', 'Xatai r.']
# 27413 ['Xatai r.']
# 27414 ['28 May m.', 'Nasimi r.']
# 27415 ['Yasamal r.']
# 27416 ['Hazi Aslanov m.', 'Xatai r.', 'Ahmadli q.']
# 27417 ['Inshaatchilar m.', 'Yasamal r.']
# 27418 ['Nasimi r.']
# 27419 ['Nasimi r.']
# 27420 ['Nasimi r.']
# 27421 ['Narimanov r.']
# 27422 ['Narimanov r.']
# 27423 ['Inshaatchilar m.', 'Yasamal r.']
# 27424 ['Yasamal r.', 'Yeni Yasamal q.']
# 27425 ['Neftchilar m.', 'Nizami r.', '8-ci kilometr q.']
# 27426 ['Xatai r.', 'Kohna Gunashli q.']
# 27427 ['Ahmadli m.', 'Xatai r.', 'Ahmadli q.']
# 27428 ['8 Noyabr m.', 'Nasimi r.', '3-cu mikrorayon q.']
# 27433 ['Inshaatchilar m.', 'Yasamal r.']
# 27434 ['Qara Qarayev m.', 'Nizami r.']
# 27435 ['Binaqadi r.', '7-ci mikrorayon q.']
# 27436 ['Nasimi r.']
# 27437 ['Elmlar Akademiyasi m.', 'Yasamal r.']
# 27438 ['Nizami m.', 'Yasamal r.']
# 27439 ['20 Yanvar m.', 'Yasamal r.']
# 27440 ['Inshaatchilar m.', 'Yasamal r.']
# 27441 ['Hazi Aslanov m.', 'Xatai r.']
# 27442 ['Ganclik m.', 'Narimanov r.']
# 27443 ['Nizami m.', 'Nasimi r.']
# 27444 ['Nasimi r.']
# 27445 ['Xatai r.', 'Ag shahar q.']
# 27446 ['Xalqlar Dostlugu m.', 'Nizami r.']
# 27447 ['Nasimi r.']
# 27448 ['Sabail r.', 'Bayil q.']
# 27449 ['Narimanov r.']
# 27450 ['Yasamal r.']
# 27451 ['Yasamal r.', 'Yeni Yasamal q.']
# 27452 ['Nariman Narimanov m.', 'Narimanov r.']
# 27453 ['Binaqadi r.', '9-cu mikrorayon q.']
# 27454 ['Nasimi r.']
# 27455 ['Xatai r.']
# 27456 ['Memar Acami m.', 'Nasimi r.', '4-cu mikrorayon q.']
# 27461 ['Binaqadi r.', '7-ci mikrorayon q.']
# 27462 ['8 Noyabr m.', 'Nasimi r.']
# 27463 ['Nizami m.', 'Yasamal r.']
# 27464 ['Xatai r.']
# 27465 ['Shah Ismayil Xatai m.', 'Xatai r.']
# 27466 ['Binaqadi r.', '9-cu mikrorayon q.']
# 27467 ['Nizami m.', 'Yasamal r.']
# 27468 ['Yasamal r.']
# 27469 ['Nizami r.']
# 27470 ['Hazi Aslanov m.', 'Xatai r.', 'Kohna Gunashli q.']
# 27471 ['Binaqadi r.', '9-cu mikrorayon q.']
# 27472 ['Narimanov r.']
# 27473 ['Binaqadi r.']
# 27474 ['Suraxani r.', 'Hovsan q.']
# 27475 ['Nasimi r.']
# 27476 ['Nariman Narimanov m.', 'Narimanov r.']
# 27477 ['Suraxani r.', 'Yeni Gunashli q.']
# 27478 ['Sabunchu r.', 'Bakixanov q.']
# 27479 ['Xatai r.']
# 27480 ['Nasimi r.']
# 27481 ['Binaqadi r.', '9-cu mikrorayon q.']
# 27482 ['Nasimi r.']
# 27483 ['Inshaatchilar m.', 'Yasamal r.']
# 27484 ['20 Yanvar m.', 'Yasamal r.']
# 27489 ['Nizami r.', '8-ci kilometr q.']
# 27490 ['Narimanov r.']
# 27491 ['28 May m.', 'Nasimi r.']
# 27492 ['Narimanov r.']
# 27493 ['Binaqadi r.']
# 27494 ['Nasimi r.']
# 27495 ['Yasamal r.', 'Elmlar Akademiyasi m.']
# 27496 ['Ahmadli m.', 'Xatai r.']
# 27497 ['Nasimi r.']
# 27498 ['Yasamal r.']
# 27499 ['Yasamal r.']
# 27500 ['Ganclik m.', 'Narimanov r.']
# 27501 ['Nizami m.', 'Yasamal r.']
# 27502 ['Yasamal r.']
# 27503 ['Nasimi r.']
# 27504 ['Narimanov r.']
# 27505 ['Narimanov r.']
# 27506 ['Binaqadi r.', '7-ci mikrorayon q.']
# 27507 ['Narimanov r.']
# 27508 ['Nizami m.', 'Yasamal r.']
# 27509 ['Nasimi r.']
# 27510 ['Neftchilar m.', 'Nizami r.', '8-ci kilometr q.']
# 27511 ['Yasamal r.', 'Yeni Yasamal q.']
# 27512 ['Nariman Narimanov m.', 'Narimanov r.']
# 27517 ['Qara Qarayev m.', 'Nizami r.', '8-ci kilometr q.']
# 27518 ['Elmlar Akademiyasi m.', 'Yasamal r.', 'Yasamal q.']
# 27519 ['Binaqadi r.', '8-ci mikrorayon q.']
# 27520 ['Qara Qarayev m.', 'Nizami r.']
# 27521 ['Inshaatchilar m.', 'Yasamal r.']
# 27522 ['Binaqadi r.', '9-cu mikrorayon q.']
# 27523 ['Sahil m.', 'Sabail r.']
# 27524 ['Xatai r.']
# 27525 ['Yasamal r.']
# 27526 ['Xatai r.', 'Hazi Aslanov q.']
# 27527 ['Elmlar Akademiyasi m.', 'Yasamal r.']
# 27528 ['Inshaatchilar m.', 'Yasamal r.']
# 27529 ['Sabail r.']
# 27530 ['Nasimi r.']
# 27531 ['Nariman Narimanov m.', 'Narimanov r.']
# 27532 ['Narimanov r.']
# 27533 ['Narimanov r.']
# 27534 ['Binaqadi r.', '9-cu mikrorayon q.']
# 27535 ['Xatai r.']
# 27536 ['Yasamal r.', 'Yeni Yasamal q.']
# 27537 ['Nasimi r.']
# 27538 ['Memar Acami m.', 'Nasimi r.', '5-ci mikrorayon q.']
# 27539 ['Neftchilar m.', 'Nizami r.', '8-ci kilometr q.']
# 27540 ['Elmlar Akademiyasi m.', 'Yasamal r.']
# 27546 ['Elmlar Akademiyasi m.', 'Yasamal r.']
# 27547 ['Memar Acami m.', 'Nasimi r.', '4-cu mikrorayon q.']
# 27548 ['Nasimi m.', 'Binaqadi r.', '6-ci mikrorayon q.']
# 27549 ['Xatai r.']
# 27550 ['28 May m.', 'Sahil m.', 'Nasimi r.']
# 27551 ['Nariman Narimanov m.', 'Narimanov r.']
# 27552 ['Shah Ismayil Xatai m.', 'Xatai r.']
# 27553 ['Binaqadi r.', '9-cu mikrorayon q.']
# 27554 ['Binaqadi r.', '9-cu mikrorayon q.']
# 27555 ['Nasimi r.']
# 27556 ['Sabail r.', 'Bayil q.']
# 27557 ['Elmlar Akademiyasi m.', 'Yasamal r.']
# 27558 ['Binaqadi r.', 'Bilacari q.']
# 27559 ['Binaqadi r.']
# 27560 ['Sabunchu r.', 'Bakixanov q.']
# 27561 ['Nariman Narimanov m.', 'Narimanov r.']
# 27562 ['Memar Acami m.', 'Nasimi r.', '4-cu mikrorayon q.']
# 27563 ['Xatai r.']
# 27564 ['Inshaatchilar m.', 'Yasamal r.']
# 27565 ['Yasamal r.', 'Yeni Yasamal q.']
# 27566 ['Narimanov r.']
# 27567 ['Yasamal r.', 'Yeni Yasamal q.']
# 27568 ['Nasimi r.']
# 27576 ['Yasamal r.']
# 27577 ['Qara Qarayev m.', 'Nizami r.']
# 27578 ['Nasimi r.']
# 27579 ['Inshaatchilar m.', 'Yasamal r.']
# 27580 ['Narimanov r.']
# 27581 ['Nasimi r.']
# 27582 ['Narimanov r.']
# 27583 ['Xalqlar Dostlugu m.', 'Nizami r.']
# 27584 ['8 Noyabr m.', 'Nasimi r.']
# 27585 ['Nizami m.', 'Nasimi r.', 'Kubinka q.']
# 27586 ['Azadliq Prospekti m.', 'Binaqadi r.', '8-ci mikrorayon q.']
# 27587 ['Qara Qarayev m.', 'Nizami r.']
# 27588 ['Elmlar Akademiyasi m.', 'Yasamal r.']
# 27589 ['Shah Ismayil Xatai m.', 'Xatai r.']
# 27590 ['Ahmadli m.', 'Xatai r.']
# 27591 ['Xatai r.', 'Ahmadli q.']
# 27592 ['Xatai r.']
# 27593 ['Xatai r.', 'Ahmadli q.']
# 27594 ['Elmlar Akademiyasi m.', 'Yasamal r.']
# 27595 ['Binaqadi r.', 'M.A.Rasulzada q.']
# 27596 ['Yasamal r.']
# 27602 ['Nizami m.', 'Nasimi r.']
# 27603 ['Inshaatchilar m.', 'Yasamal r.']
# 27604 ['Yasamal r.', 'Yasamal q.']
# 27605 ['28 May m.', 'Nasimi r.']
# 27606 ['Sahil m.', '28 May m.', 'Sabail r.']
# 27607 ['Nizami r.']
# 27608 ['Binaqadi r.', '8-ci mikrorayon q.']
# 27609 ['Xatai r.', 'Ahmadli q.']
# 27610 ['Yasamal r.']
# 27611 ['Yasamal r.', 'Yeni Yasamal q.']
# 27612 ['Nizami r.', '8-ci kilometr q.']
# 27613 ['Ganclik m.', 'Narimanov r.']
# 27614 ['Xalqlar Dostlugu m.', 'Nizami r.']
# 27615 ['Narimanov r.']
# 27616 ['Qara Qarayev m.', 'Nizami r.']
# 27617 ['Nasimi r.']
# 27618 ['Nizami m.', 'Nasimi r.']
# 27619 ['Nasimi r.']
# 27620 ['Memar Acami m.', '20 Yanvar m.', 'Nasimi r.', '5-ci mikrorayon q.']
# 27621 ['Yasamal r.']
# 27622 ['Yasamal r.']
# 27623 ['Suraxani r.', 'Hovsan q.']
# 27624 ['Xalqlar Dostlugu m.', 'Xatai r.', 'Ahmadli q.']
# 27631 ['Xatai r.', 'Ahmadli q.']
# 27632 ['Nasimi r.']
# 27633 ['Qara Qarayev m.', 'Nizami r.', '8-ci kilometr q.']
# 27634 ['Narimanov r.']
# 27635 ['Memar Acami m.', 'Nasimi r.', '5-ci mikrorayon q.']
# 27636 ['Yasamal r.', 'Yeni Yasamal q.']
# 27637 ['Xatai r.']
# 27638 ['Neftchilar m.', 'Nizami r.']
# 27639 ['Sahil m.', '28 May m.', 'Nasimi r.']
# 27640 ['Inshaatchilar m.', 'Yasamal r.']
# 27641 ['Yasamal r.', 'Yeni Yasamal q.']
# 27642 ['Binaqadi r.', '8-ci mikrorayon q.']
# 27643 ['Nasimi r.']
# 27644 ['Qara Qarayev m.', 'Nizami r.']
# 27645 ['Nizami m.', 'Nasimi r.', 'Kubinka q.']
# 27646 ['Yasamal r.']
# 27647 ['Xatai r.']
# 27648 ['Qara Qarayev m.', 'Nizami r.']
# 27649 ['Xatai r.']
# 27650 ['Nasimi r.']
# 27651 ['Narimanov r.']
# 27652 ['Yasamal r.', 'Yeni Yasamal q.']
# 27657 ['Nasimi r.']
# 27658 ['Absheron r.', 'Masazir q.']
# 27659 ['Absheron r.', 'Masazir q.']
# 27660 ['Azadliq Prospekti m.', 'Binaqadi r.', '8-ci mikrorayon q.']
# 27661 ['Nizami r.']
# 27662 ['Inshaatchilar m.', 'Yasamal r.', 'Yasamal q.']
# 27663 ['Binaqadi r.', '9-cu mikrorayon q.']
# 27664 ['Inshaatchilar m.', 'Yasamal r.']
# 27665 ['Xatai r.', 'Ahmadli q.']
# 27666 ['Nizami m.', 'Yasamal r.']
# 27667 ['Shah Ismayil Xatai m.', 'Xatai r.']
# 27668 ['20 Yanvar m.', 'Yasamal r.']
# 27669 ['Qara Qarayev m.', 'Nizami r.', '8-ci kilometr q.']
# 27670 ['Absheron r.', 'Masazir q.']
# 27671 ['Inshaatchilar m.', 'Yasamal r.']
# 27672 ['20 Yanvar m.', 'Yasamal r.']
# 27673 ['Ichari Shahar m.', 'Yasamal r.']
# 27674 ['20 Yanvar m.', 'Yasamal r.']
# 27675 ['Narimanov r.']
# 27676 ['Yasamal r.', 'Yeni Yasamal q.']
# 27677 ['Ichari Shahar m.', 'Sabail r.']
# 27678 ['Nizami m.', 'Yasamal r.']
# 27679 ['Narimanov r.']
# 27680 ['Nasimi r.']
# 27685 ['Narimanov r.']
# 27686 ['Shah Ismayil Xatai m.', 'Xatai r.']
# 27687 ['Nasimi r.']
# 27688 ['Narimanov r.']
# 27689 ['Nariman Narimanov m.', 'Narimanov r.']
# 27690 ['Yasamal r.']
# 27691 ['Narimanov r.']
# 27692 ['Nasimi r.']
# 27693 ['Nariman Narimanov m.', 'Narimanov r.']
# 27694 ['Nariman Narimanov m.', 'Narimanov r.']
# 27695 ['Sabail r.', 'Bayil q.']
# 27696 ['Elmlar Akademiyasi m.', 'Yasamal r.']
# 27697 ['Shah Ismayil Xatai m.', 'Xatai r.']
# 27698 ['Inshaatchilar m.', 'Yasamal r.']
# 27699 ['Xatai r.']
# 27700 ['Yasamal r.', 'Yeni Yasamal q.']
# 27701 ['Elmlar Akademiyasi m.', 'Yasamal r.']
# 27702 ['Nizami r.', '8-ci kilometr q.']
# 27703 ['Binaqadi r.', '9-cu mikrorayon q.']
# 27704 ['Sabail r.', 'Bayil q.']
# 27705 ['Sahil m.', 'Sabail r.']
# 27706 ['Yasamal r.']
# 27707 ['Nizami m.', 'Yasamal r.']
# 27708 ['Xatai r.', 'Ahmadli q.']
# 27713 ['Nasimi r.']
# 27714 ['Yasamal r.', 'Yeni Yasamal q.']
# 27715 ['Elmlar Akademiyasi m.', 'Yasamal r.']
# 27716 ['Yasamal r.', 'Yeni Yasamal q.']
# 27717 ['Narimanov r.']
# 27718 ['Inshaatchilar m.', 'Yasamal r.', 'Yasamal q.']
# 27719 ['8 Noyabr m.', 'Yasamal r.']
# 27720 ['Sabail r.', 'Badamdar q.']
# 27721 ['Sabunchu r.', 'Bakixanov q.']
# 27722 ['Qara Qarayev m.', 'Nizami r.', '8-ci kilometr q.']
# 27723 ['Sabunchu r.', 'Bakixanov q.']
# 27724 ['Xatai r.', 'Ahmadli q.']
# 27725 ['Binaqadi r.', 'M.A.Rasulzada q.']
# 27726 ['Inshaatchilar m.', 'Yasamal r.']
# 27727 ['Ganclik m.', 'Narimanov r.']
# 27728 ['Nasimi r.', '3-cu mikrorayon q.']
# 27729 ['Yasamal r.']
# 27730 ['Binaqadi r.', '9-cu mikrorayon q.']
# 27731 ['Memar Acami m.', 'Nasimi r.']
# 27732 ['Ahmadli m.', 'Xatai r.']
# 27733 ['Nariman Narimanov m.', 'Narimanov r.']
# 27734 ['Yasamal r.']
# 27735 ['Nizami r.']
# 27736 ['28 May m.', 'Nasimi r.']
# 27741 ['Hazi Aslanov m.', 'Xatai r.']
# 27742 ['Neftchilar m.', 'Nizami r.', '8-ci kilometr q.']
# 27743 ['Xatai r.', 'Ag shahar q.']
# 27744 ['Inshaatchilar m.', 'Yasamal r.']
# 27745 ['Inshaatchilar m.', 'Yasamal r.']
# 27746 ['Absheron r.']
# 27747 ['Yasamal r.', 'Yeni Yasamal q.']
# 27748 ['Yasamal r.']
# 27749 ['Nariman Narimanov m.', 'Narimanov r.']
# 27750 ['Azadliq Prospekti m.', 'Binaqadi r.', '8-ci mikrorayon q.']
# 27751 ['Xatai r.']
# 27752 ['Azadliq Prospekti m.', 'Binaqadi r.', '8-ci mikrorayon q.']
# 27753 ['Nasimi r.']
# 27754 ['Nizami r.', '8-ci kilometr q.']
# 27755 ['Narimanov r.']
# 27756 ['Xatai r.', 'Ahmadli q.']
# 27757 ['Xatai r.']
# 27758 ['Nasimi r.']
# 27759 ['Neftchilar m.', 'Xalqlar Dostlugu m.', 'Nizami r.', '8-ci kilometr q.']
# 27760 ['Shah Ismayil Xatai m.', 'Xatai r.']
# 27761 ['Nasimi r.']
# 27762 ['Inshaatchilar m.', 'Yasamal r.']
# 27763 ['Yasamal r.']
# 27764 ['Yasamal r.']
# 27769 ['Inshaatchilar m.', 'Yasamal r.']
# 27770 ['20 Yanvar m.', 'Yasamal r.']
# 27771 ['Yasamal r.', 'Yasamal q.']
# 27772 ['Nariman Narimanov m.', 'Narimanov r.']
# 27773 ['Xalqlar Dostlugu m.', 'Nizami r.']
# 27774 ['Elmlar Akademiyasi m.', 'Yasamal r.']
# 27775 ['Narimanov r.']
# 27776 ['Ichari Shahar m.', 'Sabail r.']
# 27777 ['Xatai r.', 'Ahmadli q.']
# 27778 ['Absheron r.']
# 27779 ['Qara Qarayev m.', 'Nizami r.']
# 27780 ['Nizami r.']
# 27781 ['Sahil m.', 'Sabail r.']
# 27782 ['Narimanov r.']
# 27783 ['Nasimi r.']
# 27784 ['Qara Qarayev m.', 'Nizami r.']
# 27785 ['Binaqadi r.', '9-cu mikrorayon q.']
# 27786 ['Neftchilar m.', 'Nizami r.', '8-ci kilometr q.']
# 27787 ['Elmlar Akademiyasi m.', 'Yasamal r.']
# 27788 ['Xatai r.', 'Hazi Aslanov q.']
# 27789 ['Ganclik m.', 'Narimanov r.']
# 27790 ['8 Noyabr m.', 'Nasimi r.']
# 27791 ['Xatai r.', 'Ahmadli q.']
# 27792 ['Xatai r.']
# 27797 ['Elmlar Akademiyasi m.', 'Yasamal r.']
# 27798 ['Koroglu m.', 'Nizami r.', '8-ci kilometr q.']
# 27799 ['Yasamal r.', 'Yeni Yasamal q.']
# 27800 ['Yasamal r.', 'Yeni Yasamal q.']
# 27801 ['Yasamal r.']
# 27802 ['Binaqadi r.', 'Bilacari q.']
# 27803 ['Elmlar Akademiyasi m.', 'Yasamal r.']
# 27804 ['Nizami r.']
# 27805 ['Yasamal r.']
# 27806 ['Nasimi r.']
# 27807 ['Suraxani r.', 'Yeni Gunashli q.']
# 27808 ['Xatai r.', 'Ahmadli q.']
# 27809 ['Yasamal r.', 'Yasamal q.']
# 27810 ['Hazi Aslanov m.', 'Xatai r.']
# 27811 ['8 Noyabr m.', 'Nasimi r.']
# 27812 ['Xatai r.', 'Ahmadli q.']
# 27813 ['Nasimi r.']
# 27814 ['Nasimi r.']
# 27815 ['Yasamal r.', 'Yeni Yasamal q.']
# 27816 ['Yasamal r.', 'Yeni Yasamal q.']
# 27817 ['Elmlar Akademiyasi m.', 'Yasamal r.']
# 27818 ['Narimanov r.']
# 27819 ['Sabail r.', 'Bayil q.']
# 27820 ['Binaqadi r.']
# 27826 ['Xatai r.', 'Ahmadli q.']
# 27827 ['Yasamal r.', 'Yeni Yasamal q.']
# 27828 ['Nasimi r.']
# 27829 ['28 May m.', 'Nasimi r.']
# 27830 ['28 May m.', 'Narimanov r.']
# 27831 ['Elmlar Akademiyasi m.', 'Yasamal r.']
# 27832 ['Yasamal r.', 'Yeni Yasamal q.']
# 27833 ['Nasimi r.']
# 27834 ['Sabail r.']
# 27835 ['Xatai r.', 'Ahmadli q.']
# 27836 ['Nizami m.', 'Yasamal r.']
# 27837 ['8 Noyabr m.', 'Nasimi r.']
# 27838 ['8 Noyabr m.', 'Nasimi r.']
# 27839 ['Ichari Shahar m.', 'Sabail r.']
# 27840 ['Neftchilar m.', 'Nizami r.', '8-ci kilometr q.']
# 27841 ['Binaqadi r.']
# 27842 ['Nizami m.', 'Nasimi r.']
# 27843 ['Yasamal r.', 'Yasamal q.']
# 27844 ['Xatai r.', 'Ahmadli q.']
# 27845 ['Xalqlar Dostlugu m.', 'Nizami r.', '8-ci kilometr q.']

# %%
df.iloc[0]
# Out:
# ID                                                   2827728
# Seller                                                 Owner
# Category                                        Kohna tikili
# Locations    [Memar Acami m., Nasimi r., 4-cu mikrorayon q.]
# Price                                                  89500
# Currency                                                 AZN
# Rooms                                                      2
# Area                                                    45.0
# Floor                                                      3
# Name: 0, dtype: object
